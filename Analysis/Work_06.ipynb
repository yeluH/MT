# %%
import torch
torch.cuda.empty_cache()

# %%
import torchvision
print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.0.1+cu117
# Torchvision version: 0.15.2+cu117
# CUDA is available: True

# %%
#pip install folium

# %%
import os 
os.environ['MPLCONFIGDIR'] = os.getcwd() + "/configs/"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:100000"
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import cv2
os.getcwd()
# Out:
# '/home/yelhe/script/mt'

# %%
import glob
import shapely
from shapely.geometry import Point, Polygon
import shapely.plotting
import pandas as pd
from PIL import Image as ima
import warnings
from pathlib import Path
import pandas as pd
import pyproj
import shapefile as shp
import seaborn as sns
import geopandas as gpd
import folium

# %%
# read the dataset and extract location
df_raw = pd.read_excel('/home/yelhe/data/Acc/E_Trottis_Unfallbericht_2019-2022.xlsx',sheet_name=None)

# %%
koord = df_raw['Allgemeine Angaben'][['Unfall-Nr.','Koord E', 'Koord N']]

# %%
koord
# Out:
#          Unfall-Nr.  Koord E  Koord N
# 0    99900060852597  2678534  1249396
# 1    99900063018611  2678534  1251496
# 2    99900052723510  2678561  1249232
# 3    99900061514043  2678640  1250202
# 4    99900063037843  2678733  1251201
# ..              ...      ...      ...
# 345  99900055905276  2686563  1250608
# 346  99900060670975  2686780  1250693
# 347  99900047367168  2687008  1250881
# 348  99900050714619  2687022  1250538
# 349  99900060734330  2687220  1250648
#
# [350 rows x 3 columns]

# %%
koord = koord.assign(lat = None, lon = None)
transformer = pyproj.Transformer.from_crs("EPSG:2056", "EPSG:4326")
# a latitude; b longitude
a, b = transformer.transform(koord[['Koord E']], koord[['Koord N']])

# %%
koord = koord.assign(lon = b, lat = a)
koord.head()
# Out:
#        Unfall-Nr.  Koord E  Koord N        lat       lon
# 0  99900060852597  2678534  1249396  47.390709  8.478805
# 1  99900063018611  2678534  1251496  47.409596  8.479174
# 2  99900052723510  2678561  1249232  47.389231  8.479134
# 3  99900061514043  2678640  1250202  47.397946  8.480350
# 4  99900063037843  2678733  1251201  47.406919  8.481758

# %%
koord.rename(columns = {'Unfall-Nr.': 'Nr'}, inplace = True)

# %%
koord.head()
# Out:
#                Nr  Koord E  Koord N        lat       lon
# 0  99900060852597  2678534  1249396  47.390709  8.478805
# 1  99900063018611  2678534  1251496  47.409596  8.479174
# 2  99900052723510  2678561  1249232  47.389231  8.479134
# 3  99900061514043  2678640  1250202  47.397946  8.480350
# 4  99900063037843  2678733  1251201  47.406919  8.481758

# %%
convert_d = {'Nr' : int}
koord = koord.astype(convert_d)

# %%
koord.head()
# Out:
#                Nr  Koord E  Koord N        lat       lon
# 0  99900060852597  2678534  1249396  47.390709  8.478805
# 1  99900063018611  2678534  1251496  47.409596  8.479174
# 2  99900052723510  2678561  1249232  47.389231  8.479134
# 3  99900061514043  2678640  1250202  47.397946  8.480350
# 4  99900063037843  2678733  1251201  47.406919  8.481758

# %%
koord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Nr       350 non-null    int64
#  1   Koord E  350 non-null    int64
#  2   Koord N  350 non-null    int64
#  3   lat      350 non-null    float64
#  4   lon      350 non-null    float64
# dtypes: float64(2), int64(3)
# memory usage: 13.8 KB

# %%
sf = shp.Reader('/home/yelhe/data/ch/Stadtkreis.shp')

plt.figure()
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.show()

# %%
sf

# %%
crs={'init':'epsg:4326'}
geometry=[Point(xy) for xy in zip(koord['lon'], koord['lat'])]
geodata=gpd.GeoDataFrame(koord, crs=crs, geometry=geometry)
# Out:
# /home/yelhe/.local/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
ch = gpd.read_file('/home/yelhe/data/ch/Stadtkreis.shp')

# %%
ch.crs
# Out:
# <Projected CRS: EPSG:2056>
# Name: CH1903+ / LV95
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Liechtenstein; Switzerland.
# - bounds: (5.96, 45.82, 10.49, 47.81)
# Coordinate Operation:
# - name: Swiss Oblique Mercator 1995
# - method: Hotine Oblique Mercator (variant B)
# Datum: CH1903+
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
ch = ch.to_crs(epsg=4326)

# %%
ch.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
geodata
# Out:
#                  Nr  Koord E  Koord N        lat       lon  \
# 0    99900060852597  2678534  1249396  47.390709  8.478805
# 1    99900063018611  2678534  1251496  47.409596  8.479174
# 2    99900052723510  2678561  1249232  47.389231  8.479134
# 3    99900061514043  2678640  1250202  47.397946  8.480350
# 4    99900063037843  2678733  1251201  47.406919  8.481758
# ..              ...      ...      ...        ...       ...
# 345  99900055905276  2686563  1250608  47.400603  8.585369
# 346  99900060670975  2686780  1250693  47.401339  8.588260
# 347  99900047367168  2687008  1250881  47.403000  8.591316
# 348  99900050714619  2687022  1250538  47.399913  8.591435
# 349  99900060734330  2687220  1250648  47.400876  8.594079
#
#                      geometry
# 0    POINT (8.47880 47.39071)
# 1    POINT (8.47917 47.40960)
# 2    POINT (8.47913 47.38923)
# 3    POINT (8.48035 47.39795)
# 4    POINT (8.48176 47.40692)
# ..                        ...
# 345  POINT (8.58537 47.40060)
# 346  POINT (8.58826 47.40134)
# 347  POINT (8.59132 47.40300)
# 348  POINT (8.59143 47.39991)
# 349  POINT (8.59408 47.40088)
#
# [350 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(7,7))
ch.plot(ax=ax, facecolor='Grey', edgecolor='k',alpha = 0.5,linewidth=1,cmap="Blues")

geodata.plot(ax=ax, color='red', markersize=5);

# fig.suptitle('Random locations', fontsize=12)
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium')
# Out:
# Text(32.347222222222214, 0.5, 'Latitude')

# %%
curb  = pd.read_csv('/home/yelhe/script/mt/curb.csv')

# %%
curb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mask               31 non-null     int64
#  1   gmedian            31 non-null     float64
#  2   rmedian            31 non-null     float64
#  3   bmedian            31 non-null     float64
#  4   gmean              31 non-null     float64
#  5   rmean              31 non-null     float64
#  6   bmean              31 non-null     float64
#  7   gstd               31 non-null     float64
#  8   rstd               31 non-null     float64
#  9   bstd               31 non-null     float64
#  10  isconvex           31 non-null     bool
#  11  area               31 non-null     float64
#  12  aspect_ratio_wh_s  31 non-null     float64
#  13  extent_s           31 non-null     float64
#  14  solidity           31 non-null     float64
#  15  aspect_ratio_wh    31 non-null     float64
#  16  extent             31 non-null     float64
#  17  ed                 31 non-null     float64
#  18  ratio_ell          31 non-null     float64
#  19  perimeter          31 non-null     float64
#  20  is_cen_inside      31 non-null     float64
#  21  is_mce_inside      31 non-null     float64
#  22  Nr                 31 non-null     int64
#  23  label              31 non-null     object
# dtypes: bool(1), float64(20), int64(2), object(1)
# memory usage: 5.7+ KB

# %%
curb.rename(columns = {'Nr': 'Nrc'}, inplace = True)

# %%
#curb = curb.drop(['label'], axis=1)
convert_d = {'Nrc' : str}
curb = curb.astype(convert_d)
# curb = curb.astype('float')

# %%
curb['no'] = curb.Nrc.str[-1:]

# %%
curb['Nr'] = curb.Nrc.str[-15:-1]

# %%
curb.head()
# Out:
#    mask  gmedian  rmedian  bmedian       gmean       rmean       bmean  \
# 0    37    136.0    137.0    134.0  134.012319  133.723621  130.664167
# 1    43    146.0    145.0    141.0  144.754717  144.268505  140.157475
# 2    38    147.0    116.0    145.0  144.381842  113.368491  141.754339
# 3    11     97.0     96.0    100.0   98.405529   97.829451  101.500544
# 4    12    200.0    177.0    206.0  182.715519  166.655640  187.292581
#
#         gstd       rstd       bstd  ...    extent          ed  ratio_ell  \
# 0  40.583695  40.455490  39.941001  ...  0.553211   33.520649  27.305327
# 1  17.221874  17.422036  17.144202  ...  0.206126   39.323650   2.051900
# 2  36.137713  36.565911  37.018719  ...  0.676940   28.277101  25.889252
# 3  15.845957  16.355386  16.633390  ...  0.571356  105.863376  13.401971
# 4  38.612772  41.268839  37.897827  ...  0.736828  126.421277  42.909823
#
#      perimeter  is_cen_inside  is_mce_inside              Nrc  label  no  \
# 0   420.149276            1.0            1.0  999000608525971   curb   1
# 1   385.889390           -1.0           -1.0  999000608525971   curb   1
# 2   254.911687            1.0            1.0  999000527235101   curb   1
# 3   695.494508            1.0            1.0  999000466623001   curb   1
# 4  1384.658942            1.0            1.0  999000601646161   curb   1
#
#                Nr
# 0  99900060852597
# 1  99900060852597
# 2  99900052723510
# 3  99900046662300
# 4  99900060164616
#
# [5 rows x 26 columns]

# %%
convert_d = {'Nr' : int}
curb = curb.astype(convert_d)

# %%
curb_loc = pd.merge(curb, koord, on = 'Nr')

# %%
curb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mask               31 non-null     int64
#  1   gmedian            31 non-null     float64
#  2   rmedian            31 non-null     float64
#  3   bmedian            31 non-null     float64
#  4   gmean              31 non-null     float64
#  5   rmean              31 non-null     float64
#  6   bmean              31 non-null     float64
#  7   gstd               31 non-null     float64
#  8   rstd               31 non-null     float64
#  9   bstd               31 non-null     float64
#  10  isconvex           31 non-null     bool
#  11  area               31 non-null     float64
#  12  aspect_ratio_wh_s  31 non-null     float64
#  13  extent_s           31 non-null     float64
#  14  solidity           31 non-null     float64
#  15  aspect_ratio_wh    31 non-null     float64
#  16  extent             31 non-null     float64
#  17  ed                 31 non-null     float64
#  18  ratio_ell          31 non-null     float64
#  19  perimeter          31 non-null     float64
#  20  is_cen_inside      31 non-null     float64
#  21  is_mce_inside      31 non-null     float64
#  22  Nrc                31 non-null     object
#  23  label              31 non-null     object
#  24  no                 31 non-null     object
#  25  Nr                 31 non-null     int64
# dtypes: bool(1), float64(20), int64(2), object(3)
# memory usage: 6.2+ KB

# %%
curb_loc
# Out:
#     mask  gmedian  rmedian  bmedian       gmean       rmean       bmean  \
# 0     37    136.0    137.0    134.0  134.012319  133.723621  130.664167
# 1     43    146.0    145.0    141.0  144.754717  144.268505  140.157475
# 2     34    134.0    134.0    132.0  123.580189  122.729363  120.767099
# 3     38    147.0    116.0    145.0  144.381842  113.368491  141.754339
# 4     37    190.0    166.0    206.0  182.622540  158.833631  198.942755
# 5     24    197.0    176.0    213.0  184.124786  162.343590  199.958974
# 6     25    198.5    176.0    209.0  185.300414  164.210635  197.111878
# 7     11     97.0     96.0    100.0   98.405529   97.829451  101.500544
# 8     12    200.0    177.0    206.0  182.715519  166.655640  187.292581
# 9     32    193.0    165.0    205.0  180.088928  152.537053  191.454228
# 10    38    186.5    165.0    196.0  182.059140  161.163978  192.521505
# 11    15    140.0    128.0    145.0  133.099011  120.500363  138.436882
# 12    19    200.0    182.0    209.0  184.979452  169.206784  194.303979
# 13    23    206.0    185.0    216.0  190.589310  174.962138  200.896659
# 14    28    193.0    174.0    199.0  177.701661  161.022591  184.525581
# 15    13    137.0    124.0    143.0  131.550113  117.974755  137.252449
# 16    30    209.0    187.0    219.0  191.878557  174.611959  201.398763
# 17    32    209.0    187.0    219.0  191.844169  174.559340  201.361610
# 18    46    144.0    131.0    148.0  139.309783  127.376359  143.847826
# 19    12     96.0     85.0     94.0   91.120361   80.729431   88.903377
# 20    14     96.0     85.0     94.0   91.251519   80.902060   89.046928
# 21    19     96.0     86.0     94.0   93.510211   82.721831   91.470775
# 22    24    130.0    120.0    136.0  121.331169  112.152302  127.326446
# 23    30    130.0    120.0    135.5  121.041128  111.851939  127.026439
# 24    22    123.0    115.0    128.0  116.203865  107.738778  121.664589
# 25    26    120.0    109.0    124.0  115.231423  104.375796  119.055202
# 26    38    141.0    147.0    133.0  135.013997  141.206055  127.217448
# 27    29    152.0    161.0    141.0  151.068213  160.224420  140.558663
# 28    27     63.0     55.0     66.0   89.028969   79.259560   93.177289
# 29    21     67.0     58.5     70.0   93.295082   84.273026   97.306557
# 30    15    146.0    147.0    144.0  155.482919  152.791925  154.987578
#
#          gstd       rstd       bstd  ...  is_cen_inside  is_mce_inside  \
# 0   40.583695  40.455490  39.941001  ...            1.0            1.0
# 1   17.221874  17.422036  17.144202  ...           -1.0           -1.0
# 2   44.923330  44.850885  44.492533  ...            1.0            1.0
# 3   36.137713  36.565911  37.018719  ...            1.0            1.0
# 4   28.576588  27.630113  29.788826  ...            1.0            1.0
# 5   31.732210  31.523697  32.157279  ...            1.0            1.0
# 6   36.484390  34.720299  37.153890  ...            1.0            1.0
# 7   15.845957  16.355386  16.633390  ...            1.0            1.0
# 8   38.612772  41.268839  37.897827  ...            1.0            1.0
# 9   37.369837  34.047881  37.639139  ...            1.0            1.0
# 10  24.833786  24.953020  24.720417  ...            1.0            1.0
# 11  49.375908  49.313448  48.633175  ...            1.0            1.0
# 12  39.859185  38.100508  40.498173  ...            1.0            1.0
# 13  35.808333  33.549058  36.215859  ...            1.0            1.0
# 14  38.812207  37.421166  38.699775  ...            1.0            1.0
# 15  38.853758  39.847587  37.933602  ...            1.0            1.0
# 16  37.164326  34.096902  37.440275  ...            1.0            1.0
# 17  37.224334  34.204026  37.520417  ...            1.0            1.0
# 18  48.360559  48.541454  47.873772  ...            1.0            1.0
# 19  23.627236  20.963211  23.553854  ...            1.0            1.0
# 20  23.550108  20.875013  23.473292  ...            1.0            1.0
# 21  23.854486  22.612973  24.190599  ...            1.0            1.0
# 22  30.194560  29.012279  31.251149  ...            1.0           -1.0
# 23  30.363999  29.191059  31.436092  ...            1.0           -1.0
# 24  28.209918  27.972996  28.301234  ...            1.0            1.0
# 25  29.680122  27.886326  30.276547  ...            1.0            1.0
# 26  27.671073  27.614750  27.604482  ...            1.0            1.0
# 27  16.121029  16.431576  16.414886  ...            1.0            1.0
# 28  55.537553  55.272734  56.860198  ...            1.0            1.0
# 29  55.954678  55.502055  57.131624  ...            1.0            1.0
# 30  37.751616  37.376507  37.827190  ...            1.0            1.0
#
#                 Nrc  label  no              Nr  Koord E  Koord N        lat  \
# 0   999000608525971   curb   1  99900060852597  2678534  1249396  47.390709
# 1   999000608525971   curb   1  99900060852597  2678534  1249396  47.390709
# 2   999000608525972   curb   2  99900060852597  2678534  1249396  47.390709
# 3   999000527235101   curb   1  99900052723510  2678561  1249232  47.389231
# 4   999000527235102   curb   2  99900052723510  2678561  1249232  47.389231
# 5   999000527235103   curb   3  99900052723510  2678561  1249232  47.389231
# 6   999000527235103   curb   3  99900052723510  2678561  1249232  47.389231
# 7   999000466623001   curb   1  99900046662300  2678978  1249165  47.388579
# 8   999000601646161   curb   1  99900060164616  2679220  1246860  47.367820
# 9   999000601646162   curb   2  99900060164616  2679220  1246860  47.367820
# 10  999000601646163   curb   3  99900060164616  2679220  1246860  47.367820
# 11  999000495072791   curb   1  99900049507279  2679250  1249460  47.391199
# 12  999000495072792   curb   2  99900049507279  2679250  1249460  47.391199
# 13  999000495072792   curb   2  99900049507279  2679250  1249460  47.391199
# 14  999000495072793   curb   3  99900049507279  2679250  1249460  47.391199
# 15  999000495072794   curb   4  99900049507279  2679250  1249460  47.391199
# 16  999000495072794   curb   4  99900049507279  2679250  1249460  47.391199
# 17  999000495072794   curb   4  99900049507279  2679250  1249460  47.391199
# 18  999000495072794   curb   4  99900049507279  2679250  1249460  47.391199
# 19  999000630186112   curb   2  99900063018611  2678534  1251496  47.409596
# 20  999000630186112   curb   2  99900063018611  2678534  1251496  47.409596
# 21  999000630186113   curb   3  99900063018611  2678534  1251496  47.409596
# 22  999000542882092   curb   2  99900054288209  2678833  1249088  47.387904
# 23  999000542882092   curb   2  99900054288209  2678833  1249088  47.387904
# 24  999000542882094   curb   4  99900054288209  2678833  1249088  47.387904
# 25  999000542882094   curb   4  99900054288209  2678833  1249088  47.387904
# 26  999000639922122   curb   2  99900063992212  2679059  1249645  47.392886
# 27  999000639922124   curb   4  99900063992212  2679059  1249645  47.392886
# 28  999000615140433   curb   3  99900061514043  2678640  1250202  47.397946
# 29  999000615140434   curb   4  99900061514043  2678640  1250202  47.397946
# 30  999000630378433   curb   3  99900063037843  2678733  1251201  47.406919
#
#          lon
# 0   8.478805
# 1   8.478805
# 2   8.478805
# 3   8.479134
# 4   8.479134
# 5   8.479134
# 6   8.479134
# 7   8.484644
# 8   8.487441
# 9   8.487441
# 10  8.487441
# 11  8.488298
# 12  8.488298
# 13  8.488298
# 14  8.488298
# 15  8.488298
# 16  8.488298
# 17  8.488298
# 18  8.488298
# 19  8.479174
# 20  8.479174
# 21  8.479174
# 22  8.482710
# 23  8.482710
# 24  8.482710
# 25  8.482710
# 26  8.485802
# 27  8.485802
# 28  8.480350
# 29  8.480350
# 30  8.481758
#
# [31 rows x 30 columns]

# %%
crs={'init':'epsg:4326'}
geometry_c=[Point(xy) for xy in zip(curb_loc['lon'], curb_loc['lat'])]
geodata_c=gpd.GeoDataFrame(curb_loc, crs=crs, geometry=geometry_c)
# geodata_c.plot()
#ch = gpd.read_file('/home/yelhe/data/ch/Stadtkreis.shp')
fig, ax = plt.subplots(figsize=(7,7))
ch.plot(ax=ax, facecolor='Grey', edgecolor='k',alpha = 0.5,linewidth=0.8,cmap="Blues")

geodata_c.plot(ax=ax, color='red', markersize=5);


# fig.suptitle('Random locations', fontsize=12)
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium')
# Out:
# /home/yelhe/.local/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# Text(32.347222222222214, 0.5, 'Latitude')
