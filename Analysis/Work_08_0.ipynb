# %%
import torch
torch.cuda.empty_cache()

# %%
import torchvision
print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.0.1+cu117
# Torchvision version: 0.15.2+cu117
# CUDA is available: True

# %%
import os 
os.environ['MPLCONFIGDIR'] = os.getcwd() + "/configs/"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:100000"
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import cv2
os.getcwd()
# Out:
# '/home/yelhe/script/mt'

# %%
import glob
import shapely
from shapely.geometry import Polygon
import shapely.plotting

# %%
import pandas as pd
from PIL import Image as ima
import warnings

# %%
from mt_function_yl import *

# %%
df = pd.read_csv('/home/yelhe/script/mt/input/df_all_new1.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3934 entries, 0 to 3933
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mask               3934 non-null   int64
#  1   gmedian            3934 non-null   float64
#  2   rmedian            3934 non-null   float64
#  3   bmedian            3934 non-null   float64
#  4   gmean              3934 non-null   float64
#  5   rmean              3934 non-null   float64
#  6   bmean              3934 non-null   float64
#  7   gstd               3934 non-null   float64
#  8   rstd               3934 non-null   float64
#  9   bstd               3934 non-null   float64
#  10  gq25               3934 non-null   float64
#  11  gq75               3934 non-null   float64
#  12  rq25               3934 non-null   float64
#  13  rq75               3934 non-null   float64
#  14  bq25               3934 non-null   float64
#  15  bq75               3934 non-null   float64
#  16  cdmean             3934 non-null   float64
#  17  cdstd              3934 non-null   float64
#  18  isconvex           3934 non-null   int64
#  19  area               3934 non-null   float64
#  20  aspect_ratio_wh_s  3934 non-null   float64
#  21  extent_s           3934 non-null   float64
#  22  solidity           3934 non-null   float64
#  23  aspect_ratio_wh    3934 non-null   float64
#  24  extent             3934 non-null   float64
#  25  orien_rre          3934 non-null   float64
#  26  orien_ell          3934 non-null   float64
#  27  ed                 3934 non-null   float64
#  28  ratio_ell          3934 non-null   float64
#  29  perimeter          3934 non-null   float64
#  30  is_cen_inside      3934 non-null   float64
#  31  is_mce_inside      3934 non-null   float64
#  32  leftm              3934 non-null   int64
#  33  rightm             3934 non-null   int64
#  34  topm               3934 non-null   int64
#  35  bottomm            3934 non-null   int64
#  36  label              3934 non-null   object
#  37  Nr                 3934 non-null   int64
#  38  label_group        3934 non-null   object
# dtypes: float64(30), int64(7), object(2)
# memory usage: 1.2+ MB

# %%
df = df.replace({True:1, False:0})

# %% [markdown]
# ### Library Preparation

# %%
# Importing Modules

from sklearn import * 
from sklearn import datasets
from sklearn.datasets import load_digits

from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.cluster import HDBSCAN
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve

from sklearn import linear_model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import LabelEncoder

from sklearn import svm

import seaborn as sn

# %%
df.describe()
# Out:
#               mask      gmedian      rmedian      bmedian        gmean  \
# count  3934.000000  3934.000000  3934.000000  3934.000000  3934.000000
# mean     28.102440   107.681749   100.183401   106.295755   109.127158
# std      18.414498    54.526821    57.441065    56.676323    50.180583
# min       1.000000     1.000000     2.000000     2.000000     2.936775
# 25%      14.000000    68.000000    52.000000    62.000000    72.320588
# 50%      26.000000   101.000000    96.000000    99.000000   104.444885
# 75%      39.000000   144.000000   137.000000   144.000000   142.042793
# max     106.000000   255.000000   255.000000   255.000000   254.839997
#
#              rmean        bmean         gstd         rstd         bstd  ...  \
# count  3934.000000  3934.000000  3934.000000  3934.000000  3934.000000  ...
# mean    102.028022   107.701587    32.921114    32.992329    33.063943  ...
# std      53.022707    52.341292    15.522335    16.047631    15.211095  ...
# min       5.470320     5.073171     0.966019     1.076037     0.984394  ...
# 25%      58.401686    66.481011    21.114186    20.398521    21.631473  ...
# 50%      99.833912   100.606188    31.884037    31.754133    31.781912  ...
# 75%     134.371990   141.815392    42.606793    43.386159    42.230066  ...
# max     254.784007   254.851574    98.309030    98.262223    98.221301  ...
#
#                 ed    ratio_ell    perimeter  is_cen_inside  is_mce_inside  \
# count  3934.000000  3934.000000  3934.000000    3934.000000    3934.000000
# mean     65.691370     5.549314   317.355061       0.976868       0.951195
# std      89.665225    14.094178   442.020875       0.194571       0.306149
# min       3.385138     1.009687    14.828427      -1.000000      -1.000000
# 25%      20.501906     1.582724    84.066756       1.000000       1.000000
# 50%      32.576752     2.343272   147.689862       1.000000       1.000000
# 75%      62.254161     4.426106   329.877939       1.000000       1.000000
# max     521.869570   487.911969  4028.115996       1.000000       1.000000
#
#              leftm       rightm         topm      bottomm            Nr
# count  3934.000000  3934.000000  3934.000000  3934.000000  3.934000e+03
# mean    274.200813   367.029995   289.734875   360.615150  9.990006e+14
# std     198.977944   199.225320   120.406286   110.592668  5.980060e+07
# min       0.000000     9.000000     0.000000    12.000000  9.990005e+14
# 25%      84.000000   199.000000   249.000000   312.000000  9.990005e+14
# 50%     272.000000   368.000000   307.000000   340.000000  9.990006e+14
# 75%     449.000000   556.000000   347.000000   400.000000  9.990006e+14
# max     630.000000   639.000000   625.000000   639.000000  9.990006e+14
#
# [8 rows x 37 columns]

# %%
df.loc[(df.label_group == 'means_of_transportation'), 'label_group'] = 'other'

# %%
# df_ = df_new.drop(['area', 'ed', 'perimeter'], axis=1)
le = LabelEncoder()
df['labelgroup_index'] = le.fit_transform(df['label_group'])
y = df['label_group']
y = le.transform(y)

# %%
# df.head()

# %%
df1= df
df1.groupby(['label_group','labelgroup_index']).size().reset_index().rename(columns={0:'count'})
# Out:
#       label_group  labelgroup_index  count
# 0        building                 0    401
# 1            curb                 1     49
# 2  infrastructure                 2    717
# 3           other                 3   2011
# 4             sky                 4    112
# 5      vegetation                 5    644

# %%
# 0 building; 1 curb; 2 infrastructure;
# 3 other; 4 sky; 5 vegetation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3934 entries, 0 to 3933
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mask               3934 non-null   int64
#  1   gmedian            3934 non-null   float64
#  2   rmedian            3934 non-null   float64
#  3   bmedian            3934 non-null   float64
#  4   gmean              3934 non-null   float64
#  5   rmean              3934 non-null   float64
#  6   bmean              3934 non-null   float64
#  7   gstd               3934 non-null   float64
#  8   rstd               3934 non-null   float64
#  9   bstd               3934 non-null   float64
#  10  gq25               3934 non-null   float64
#  11  gq75               3934 non-null   float64
#  12  rq25               3934 non-null   float64
#  13  rq75               3934 non-null   float64
#  14  bq25               3934 non-null   float64
#  15  bq75               3934 non-null   float64
#  16  cdmean             3934 non-null   float64
#  17  cdstd              3934 non-null   float64
#  18  isconvex           3934 non-null   int64
#  19  area               3934 non-null   float64
#  20  aspect_ratio_wh_s  3934 non-null   float64
#  21  extent_s           3934 non-null   float64
#  22  solidity           3934 non-null   float64
#  23  aspect_ratio_wh    3934 non-null   float64
#  24  extent             3934 non-null   float64
#  25  orien_rre          3934 non-null   float64
#  26  orien_ell          3934 non-null   float64
#  27  ed                 3934 non-null   float64
#  28  ratio_ell          3934 non-null   float64
#  29  perimeter          3934 non-null   float64
#  30  is_cen_inside      3934 non-null   float64
#  31  is_mce_inside      3934 non-null   float64
#  32  leftm              3934 non-null   int64
#  33  rightm             3934 non-null   int64
#  34  topm               3934 non-null   int64
#  35  bottomm            3934 non-null   int64
#  36  label              3934 non-null   object
#  37  Nr                 3934 non-null   int64
#  38  label_group        3934 non-null   object
#  39  labelgroup_index   3934 non-null   int64
# dtypes: float64(30), int64(8), object(2)
# memory usage: 1.2+ MB

# %%
dfc = df
# Drop info columns
dfc = dfc.drop(['label', 'Nr', 'label_group', 'mask', 'labelgroup_index'], axis = 1)
# Drop variables which don't help much
dfc = dfc.drop(['isconvex','is_cen_inside','is_mce_inside', 'leftm', 'rightm'], axis = 1)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3934 entries, 0 to 3933
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gmedian            3934 non-null   float64
#  1   rmedian            3934 non-null   float64
#  2   bmedian            3934 non-null   float64
#  3   gmean              3934 non-null   float64
#  4   rmean              3934 non-null   float64
#  5   bmean              3934 non-null   float64
#  6   gstd               3934 non-null   float64
#  7   rstd               3934 non-null   float64
#  8   bstd               3934 non-null   float64
#  9   gq25               3934 non-null   float64
#  10  gq75               3934 non-null   float64
#  11  rq25               3934 non-null   float64
#  12  rq75               3934 non-null   float64
#  13  bq25               3934 non-null   float64
#  14  bq75               3934 non-null   float64
#  15  cdmean             3934 non-null   float64
#  16  cdstd              3934 non-null   float64
#  17  area               3934 non-null   float64
#  18  aspect_ratio_wh_s  3934 non-null   float64
#  19  extent_s           3934 non-null   float64
#  20  solidity           3934 non-null   float64
#  21  aspect_ratio_wh    3934 non-null   float64
#  22  extent             3934 non-null   float64
#  23  orien_rre          3934 non-null   float64
#  24  orien_ell          3934 non-null   float64
#  25  ed                 3934 non-null   float64
#  26  ratio_ell          3934 non-null   float64
#  27  perimeter          3934 non-null   float64
#  28  topm               3934 non-null   int64
#  29  bottomm            3934 non-null   int64
# dtypes: float64(28), int64(2)
# memory usage: 922.2 KB

# %% [markdown]
# ## Unsupervised

# %% [markdown]
# ### Kmeans

# %%
from sklearn.cluster import KMeans
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(dfc)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('CS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 6,random_state=0, n_init="auto")
kmeans.fit(dfc)
labels = kmeans.labels_
correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))

print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 303 out of 3934 samples were correctly labeled.
# Accuracy score: 0.08

# %%
column_names = list(dfc.columns)
print(column_names)
# Out:
# ['gmedian', 'rmedian', 'bmedian', 'gmean', 'rmean', 'bmean', 'gstd', 'rstd', 'bstd', 'gq25', 'gq75', 'rq25', 'rq75', 'bq25', 'bq75', 'cdmean', 'cdstd', 'area', 'aspect_ratio_wh_s', 'extent_s', 'solidity', 'aspect_ratio_wh', 'extent', 'orien_rre', 'orien_ell', 'ed', 'ratio_ell', 'perimeter', 'topm', 'bottomm']

# %% [markdown]
# ### Hierachical clustering

# %%
#Ward, complete, average, and single linkage
hierarchical_cluster1 = AgglomerativeClustering(linkage='ward', n_clusters=6)
labels_hc = hierarchical_cluster1.fit_predict(dfc)
print(labels_hc)
hierarchical_cluster2 = AgglomerativeClustering(linkage='complete', n_clusters=6)
labels_hc2 = hierarchical_cluster2.fit_predict(dfc)
print(labels_hc2)
# Single linkage doesn't work well 
hierarchical_cluster3 = AgglomerativeClustering(linkage='single', n_clusters=6)
labels_hc3 = hierarchical_cluster3.fit_predict(dfc)
print(labels_hc3)
hierarchical_cluster4 = AgglomerativeClustering(linkage='average', n_clusters=6)
labels_hc4 = hierarchical_cluster4.fit_predict(dfc)
print(labels_hc4)
# Out:
# [0 3 0 ... 1 1 1]
# [0 2 0 ... 2 2 2]
# [0 2 0 ... 2 2 2]
# [0 3 0 ... 3 3 3]

# %%
correct_labels1 = sum(y == labels_hc)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels1, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels1/float(y.size)))
correct_labels2 = sum(y == labels_hc2)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels2, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels2/float(y.size)))
correct_labels3 = sum(y == labels_hc3)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels3, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels3/float(y.size)))
correct_labels4 = sum(y == labels_hc4)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels4, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels4/float(y.size)))
# Out:
# Result: 137 out of 3934 samples were correctly labeled.
# Accuracy score: 0.03
# Result: 624 out of 3934 samples were correctly labeled.
# Accuracy score: 0.16
# Result: 661 out of 3934 samples were correctly labeled.
# Accuracy score: 0.17
# Result: 2032 out of 3934 samples were correctly labeled.
# Accuracy score: 0.52

# %%
plt.figure(figsize=(20,20))
linkage_data = linkage(dfc, method='average', metric='euclidean')
dendrogram(linkage_data)
plt.show()

# %% [markdown]
# ### DBSCAN

# %%
cluster_db = DBSCAN(eps = 5, min_samples = 2)
labels_db = cluster_db.fit_predict(dfc)
print(labels_db)
correct_labels_db = sum(y == labels_db)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels_db, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels_db/float(y.size)))
# Out:
# [-1 -1 -1 ... -1 -1 -1]
# Result: 2 out of 3934 samples were correctly labeled.
# Accuracy score: 0.00

# %% [markdown]
# ### HDBSCAN

# %%
cluster_hdb = HDBSCAN(min_cluster_size = 2)
labels_hdb = cluster_hdb.fit_predict(dfc)
print(labels_hdb)
correct_labels_hdb = sum(y == labels_hdb)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels_hdb, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels_hdb/float(y.size)))
# Out:
# [ 47  59  47 ...  -1 704 535]
# Result: 6 out of 3934 samples were correctly labeled.
# Accuracy score: 0.00

# %% [markdown]
# ## Supervised

# %% [markdown]
# ### Decision tree

# %%
X = dfc
y = y

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 2)

# %%
dtree1 = DecisionTreeClassifier()
dtree1 = dtree1.fit(X, y)
plt.figure(figsize=(20,20))
tree.plot_tree(dtree1, feature_names = column_names, fontsize=10)
plt.savefig('/home/yelhe/script/mt/output/' + 'decisiontree0' + '.jpg')
plt.show()

# %%
plt.figure(figsize=(25,25))
tree.plot_tree(dtree1, feature_names = column_names, fontsize=10)
plt.savefig('/home/yelhe/script/mt/output/' + 'decisiontree0' + '.jpg')
plt.show()

# %%
text_representation1 = tree.export_text(dtree1, feature_names = column_names)
print(text_representation1)
# Out:
# |--- rq25 <= 51.88
# |   |--- cdmean <= 13.44
# |   |   |--- topm <= 315.50
# |   |   |   |--- extent <= 0.87
# |   |   |   |   |--- rq75 <= 48.50
# |   |   |   |   |   |--- perimeter <= 78.58
# |   |   |   |   |   |   |--- cdmean <= 9.27
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- cdmean >  9.27
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- perimeter >  78.58
# |   |   |   |   |   |   |--- bstd <= 10.25
# |   |   |   |   |   |   |   |--- cdstd <= 1.96
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- cdstd >  1.96
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- bstd >  10.25
# |   |   |   |   |   |   |   |--- gq25 <= 9.50
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- gq25 >  9.50
# |   |   |   |   |   |   |   |   |--- bottomm <= 313.50
# |   |   |   |   |   |   |   |   |   |--- gstd <= 22.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- gstd >  22.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bottomm >  313.50
# |   |   |   |   |   |   |   |   |   |--- bq75 <= 65.00
# |   |   |   |   |   |   |   |   |   |   |--- area <= 268.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- area >  268.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- bq75 >  65.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- rq75 >  48.50
# |   |   |   |   |   |--- ratio_ell <= 1.83
# |   |   |   |   |   |   |--- aspect_ratio_wh <= 1.48
# |   |   |   |   |   |   |   |--- ed <= 19.87
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 1.14
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  1.14
# |   |   |   |   |   |   |   |   |   |--- bq25 <= 52.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- bq25 >  52.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- ed >  19.87
# |   |   |   |   |   |   |   |   |--- extent_s <= 0.77
# |   |   |   |   |   |   |   |   |   |--- gmedian <= 89.50
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 272.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  272.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- gmedian >  89.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- extent_s >  0.77
# |   |   |   |   |   |   |   |   |   |--- bq75 <= 83.50
# |   |   |   |   |   |   |   |   |   |   |--- bmean <= 50.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- bmean >  50.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- bq75 >  83.50
# |   |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- extent_s >  0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- aspect_ratio_wh >  1.48
# |   |   |   |   |   |   |   |--- gmean <= 74.73
# |   |   |   |   |   |   |   |   |--- bmean <= 36.78
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bmean >  36.78
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 7.88
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cdstd >  7.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- gmean >  74.73
# |   |   |   |   |   |   |   |   |--- bottomm <= 320.50
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bottomm >  320.50
# |   |   |   |   |   |   |   |   |   |--- gmedian <= 102.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- gmedian >  102.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- ratio_ell >  1.83
# |   |   |   |   |   |   |--- bottomm <= 322.50
# |   |   |   |   |   |   |   |--- gstd <= 56.56
# |   |   |   |   |   |   |   |   |--- ed <= 19.16
# |   |   |   |   |   |   |   |   |   |--- orien_ell <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- orien_ell >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- ed >  19.16
# |   |   |   |   |   |   |   |   |   |--- ratio_ell <= 7.24
# |   |   |   |   |   |   |   |   |   |   |--- solidity <= 0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- solidity >  0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- ratio_ell >  7.24
# |   |   |   |   |   |   |   |   |   |   |--- orien_rre <= 88.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- orien_rre >  88.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- gstd >  56.56
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- bottomm >  322.50
# |   |   |   |   |   |   |   |--- cdstd <= 6.93
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 3.35
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  3.35
# |   |   |   |   |   |   |   |   |   |--- extent <= 0.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- extent >  0.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- cdstd >  6.93
# |   |   |   |   |   |   |   |   |--- perimeter <= 354.51
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 8.91
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- cdstd >  8.91
# |   |   |   |   |   |   |   |   |   |   |--- bstd <= 41.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- bstd >  41.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- perimeter >  354.51
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- extent >  0.87
# |   |   |   |   |--- aspect_ratio_wh_s <= 0.11
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- aspect_ratio_wh_s >  0.11
# |   |   |   |   |   |--- area <= 9708.50
# |   |   |   |   |   |   |--- ratio_ell <= 1.05
# |   |   |   |   |   |   |   |--- rmedian <= 46.25
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- rmedian >  46.25
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- ratio_ell >  1.05
# |   |   |   |   |   |   |   |--- rstd <= 49.44
# |   |   |   |   |   |   |   |   |--- gq25 <= 46.88
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- gq25 >  46.88
# |   |   |   |   |   |   |   |   |   |--- gmean <= 64.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- gmean >  64.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- rstd >  49.44
# |   |   |   |   |   |   |   |   |--- orien_rre <= 43.32
# |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- extent_s >  0.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- orien_rre >  43.32
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- area >  9708.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- topm >  315.50
# |   |   |   |--- perimeter <= 154.43
# |   |   |   |   |--- bstd <= 17.05
# |   |   |   |   |   |--- gmean <= 27.19
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- gmean >  27.19
# |   |   |   |   |   |   |--- bq25 <= 27.50
# |   |   |   |   |   |   |   |--- bstd <= 10.55
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- bstd >  10.55
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 3.17
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  3.17
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- bq25 >  27.50
# |   |   |   |   |   |   |   |--- rq25 <= 42.38
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- rq25 >  42.38
# |   |   |   |   |   |   |   |   |--- orien_ell <= 86.65
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- orien_ell >  86.65
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- bstd >  17.05
# |   |   |   |   |   |--- extent_s <= 0.34
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- extent_s >  0.34
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |--- perimeter >  154.43
# |   |   |   |   |--- cdmean <= 7.93
# |   |   |   |   |   |--- bq25 <= 48.88
# |   |   |   |   |   |   |--- perimeter <= 162.48
# |   |   |   |   |   |   |   |--- gmedian <= 35.00
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- gmedian >  35.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- perimeter >  162.48
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- bq25 >  48.88
# |   |   |   |   |   |   |--- perimeter <= 332.25
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- perimeter >  332.25
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- cdmean >  7.93
# |   |   |   |   |   |--- rq75 <= 45.50
# |   |   |   |   |   |   |--- gq75 <= 32.50
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- gq75 >  32.50
# |   |   |   |   |   |   |   |--- cdstd <= 9.76
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- cdstd >  9.76
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- rq75 >  45.50
# |   |   |   |   |   |   |--- gq75 <= 151.00
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- gq75 >  151.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |--- cdmean >  13.44
# |   |   |--- gq75 <= 65.50
# |   |   |   |--- bmedian <= 40.25
# |   |   |   |   |--- gmedian <= 27.50
# |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- gmedian >  27.50
# |   |   |   |   |   |--- cdmean <= 19.51
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- cdmean >  19.51
# |   |   |   |   |   |   |--- topm <= 310.50
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- topm >  310.50
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |--- bmedian >  40.25
# |   |   |   |   |--- gmedian <= 17.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- gmedian >  17.50
# |   |   |   |   |   |--- area <= 5591.25
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- area >  5591.25
# |   |   |   |   |   |   |--- aspect_ratio_wh <= 2.28
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- aspect_ratio_wh >  2.28
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- gq75 >  65.50
# |   |   |   |--- rmedian <= 58.75
# |   |   |   |   |--- topm <= 301.50
# |   |   |   |   |   |--- rq25 <= 42.00
# |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.28
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.28
# |   |   |   |   |   |   |   |--- extent <= 0.82
# |   |   |   |   |   |   |   |   |--- bstd <= 66.42
# |   |   |   |   |   |   |   |   |   |--- bstd <= 22.77
# |   |   |   |   |   |   |   |   |   |   |--- area <= 382.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- area >  382.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- bstd >  22.77
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 216.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  216.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bstd >  66.42
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- extent >  0.82
# |   |   |   |   |   |   |   |   |--- cdmean <= 15.32
# |   |   |   |   |   |   |   |   |   |--- gq75 <= 80.62
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- gq75 >  80.62
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- cdmean >  15.32
# |   |   |   |   |   |   |   |   |   |--- bmedian <= 35.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- bmedian >  35.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- rq25 >  42.00
# |   |   |   |   |   |   |--- gmedian <= 76.75
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- gmedian >  76.75
# |   |   |   |   |   |   |   |--- gstd <= 26.95
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gstd >  26.95
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |--- topm >  301.50
# |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.84
# |   |   |   |   |   |   |--- solidity <= 0.94
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- solidity >  0.94
# |   |   |   |   |   |   |   |--- bmedian <= 55.50
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- bmedian >  55.50
# |   |   |   |   |   |   |   |   |--- rstd <= 34.53
# |   |   |   |   |   |   |   |   |   |--- gstd <= 38.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- gstd >  38.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- rstd >  34.53
# |   |   |   |   |   |   |   |   |   |--- gq25 <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- gq25 >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- aspect_ratio_wh_s >  0.84
# |   |   |   |   |   |   |--- rmean <= 63.33
# |   |   |   |   |   |   |   |--- extent <= 0.80
# |   |   |   |   |   |   |   |   |--- gmedian <= 47.50
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- gmedian >  47.50
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 7.18
# |   |   |   |   |   |   |   |   |   |   |--- perimeter <= 58.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- perimeter >  58.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  7.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- extent >  0.80
# |   |   |   |   |   |   |   |   |--- bq25 <= 35.00
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bq25 >  35.00
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 9.41
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 338.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  338.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- cdstd >  9.41
# |   |   |   |   |   |   |   |   |   |   |--- gmean <= 106.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- gmean >  106.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- rmean >  63.33
# |   |   |   |   |   |   |   |--- orien_rre <= 21.26
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- orien_rre >  21.26
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |--- rmedian >  58.75
# |   |   |   |   |--- gq25 <= 69.88
# |   |   |   |   |   |--- topm <= 262.50
# |   |   |   |   |   |   |--- gmean <= 96.75
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.65
# |   |   |   |   |   |   |   |   |--- gq25 <= 37.75
# |   |   |   |   |   |   |   |   |   |--- topm <= 195.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- topm >  195.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- gq25 >  37.75
# |   |   |   |   |   |   |   |   |   |--- cdmean <= 14.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- cdmean >  14.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.65
# |   |   |   |   |   |   |   |   |--- bottomm <= 285.50
# |   |   |   |   |   |   |   |   |   |--- bq75 <= 108.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- bq75 >  108.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- bottomm >  285.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gmean >  96.75
# |   |   |   |   |   |   |   |--- gmean <= 112.06
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- gmean >  112.06
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- topm >  262.50
# |   |   |   |   |   |   |--- area <= 66.25
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- area >  66.25
# |   |   |   |   |   |   |   |--- cdmean <= 14.03
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- cdmean >  14.03
# |   |   |   |   |   |   |   |   |--- topm <= 278.00
# |   |   |   |   |   |   |   |   |   |--- extent <= 0.70
# |   |   |   |   |   |   |   |   |   |   |--- gstd <= 36.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- gstd >  36.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- extent >  0.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- topm >  278.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- gq25 >  69.88
# |   |   |   |   |   |--- gstd <= 29.33
# |   |   |   |   |   |   |--- solidity <= 0.90
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- solidity >  0.90
# |   |   |   |   |   |   |   |--- perimeter <= 53.26
# |   |   |   |   |   |   |   |   |--- ed <= 12.75
# |   |   |   |   |   |   |   |   |   |--- bstd <= 24.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- bstd >  24.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ed >  12.75
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- perimeter >  53.26
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- gstd >  29.33
# |   |   |   |   |   |   |--- orien_rre <= 5.04
# |   |   |   |   |   |   |   |--- extent <= 0.71
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- extent >  0.71
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- orien_rre >  5.04
# |   |   |   |   |   |   |   |--- bq75 <= 166.50
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- bq75 >  166.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |--- rq25 >  51.88
# |   |--- perimeter <= 249.65
# |   |   |--- extent_s <= 0.45
# |   |   |   |--- bmedian <= 112.50
# |   |   |   |   |--- rq75 <= 85.50
# |   |   |   |   |   |--- bq25 <= 75.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- bq25 >  75.50
# |   |   |   |   |   |   |--- bstd <= 21.97
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- bstd >  21.97
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- rq75 >  85.50
# |   |   |   |   |   |--- rstd <= 47.27
# |   |   |   |   |   |   |--- bq75 <= 149.88
# |   |   |   |   |   |   |   |--- cdstd <= 12.26
# |   |   |   |   |   |   |   |   |--- bmean <= 110.61
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- bmean >  110.61
# |   |   |   |   |   |   |   |   |   |--- rq75 <= 107.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- rq75 >  107.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- cdstd >  12.26
# |   |   |   |   |   |   |   |   |--- orien_rre <= 34.10
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- orien_rre >  34.10
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- bq75 >  149.88
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- rstd >  47.27
# |   |   |   |   |   |   |--- bmean <= 95.69
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- bmean >  95.69
# |   |   |   |   |   |   |   |--- ed <= 38.16
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- ed >  38.16
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- bmedian >  112.50
# |   |   |   |   |--- bottomm <= 322.00
# |   |   |   |   |   |--- extent_s <= 0.23
# |   |   |   |   |   |   |--- extent <= 0.78
# |   |   |   |   |   |   |   |--- extent <= 0.24
# |   |   |   |   |   |   |   |   |--- orien_ell <= 98.09
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- orien_ell >  98.09
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- extent >  0.24
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- extent >  0.78
# |   |   |   |   |   |   |   |--- orien_rre <= 65.99
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- orien_rre >  65.99
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- extent_s >  0.23
# |   |   |   |   |   |   |--- gmean <= 197.12
# |   |   |   |   |   |   |   |--- bmedian <= 138.50
# |   |   |   |   |   |   |   |   |--- gstd <= 26.32
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- gstd >  26.32
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- bmedian >  138.50
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- gmean >  197.12
# |   |   |   |   |   |   |   |--- rmedian <= 209.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- rmedian >  209.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- bottomm >  322.00
# |   |   |   |   |   |--- rstd <= 51.01
# |   |   |   |   |   |   |--- perimeter <= 245.74
# |   |   |   |   |   |   |   |--- bmedian <= 122.00
# |   |   |   |   |   |   |   |   |--- ed <= 9.51
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ed >  9.51
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- bmedian >  122.00
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 8.06
# |   |   |   |   |   |   |   |   |   |--- gq75 <= 127.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- gq75 >  127.50
# |   |   |   |   |   |   |   |   |   |   |--- bstd <= 35.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- bstd >  35.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  8.06
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- perimeter >  245.74
# |   |   |   |   |   |   |   |--- rq75 <= 191.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- rq75 >  191.50
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- rstd >  51.01
# |   |   |   |   |   |   |--- bmean <= 148.57
# |   |   |   |   |   |   |   |--- extent_s <= 0.27
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- extent_s >  0.27
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- bmean >  148.57
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |--- extent_s >  0.45
# |   |   |   |--- bottomm <= 327.50
# |   |   |   |   |--- bottomm <= 285.50
# |   |   |   |   |   |--- rmedian <= 213.75
# |   |   |   |   |   |   |--- bstd <= 35.02
# |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 0.14
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- aspect_ratio_wh >  0.14
# |   |   |   |   |   |   |   |   |--- bottomm <= 93.00
# |   |   |   |   |   |   |   |   |   |--- rq25 <= 69.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- rq25 >  69.50
# |   |   |   |   |   |   |   |   |   |   |--- rstd <= 37.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- rstd >  37.20
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bottomm >  93.00
# |   |   |   |   |   |   |   |   |   |--- perimeter <= 37.73
# |   |   |   |   |   |   |   |   |   |   |--- topm <= 234.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- topm >  234.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- perimeter >  37.73
# |   |   |   |   |   |   |   |   |   |   |--- ratio_ell <= 1.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- ratio_ell >  1.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- bstd >  35.02
# |   |   |   |   |   |   |   |--- area <= 808.50
# |   |   |   |   |   |   |   |   |--- extent_s <= 0.63
# |   |   |   |   |   |   |   |   |   |--- orien_rre <= 41.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- orien_rre >  41.18
# |   |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- extent_s >  0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- extent_s >  0.63
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 2.46
# |   |   |   |   |   |   |   |   |   |   |--- bmedian <= 104.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- bmedian >  104.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- cdstd >  2.46
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- area >  808.50
# |   |   |   |   |   |   |   |   |--- bmean <= 140.12
# |   |   |   |   |   |   |   |   |   |--- bottomm <= 261.50
# |   |   |   |   |   |   |   |   |   |   |--- gmean <= 101.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- gmean >  101.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- bottomm >  261.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bmean >  140.12
# |   |   |   |   |   |   |   |   |   |--- solidity <= 0.82
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- solidity >  0.82
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- rmedian >  213.75
# |   |   |   |   |   |   |--- area <= 856.25
# |   |   |   |   |   |   |   |--- rmedian <= 220.25
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 0.93
# |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  0.93
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- rmedian >  220.25
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- area >  856.25
# |   |   |   |   |   |   |   |--- bmedian <= 248.00
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |--- bmedian >  248.00
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- bottomm >  285.50
# |   |   |   |   |   |--- area <= 903.75
# |   |   |   |   |   |   |--- topm <= 301.50
# |   |   |   |   |   |   |   |--- ed <= 16.44
# |   |   |   |   |   |   |   |   |--- area <= 67.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- area >  67.00
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 6.84
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 291.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  291.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- cdstd >  6.84
# |   |   |   |   |   |   |   |   |   |   |--- topm <= 293.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- topm >  293.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- ed >  16.44
# |   |   |   |   |   |   |   |   |--- cdmean <= 26.17
# |   |   |   |   |   |   |   |   |   |--- ratio_ell <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- cdstd <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- cdstd >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- ratio_ell >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- cdmean >  26.17
# |   |   |   |   |   |   |   |   |   |--- bmedian <= 109.50
# |   |   |   |   |   |   |   |   |   |   |--- perimeter <= 65.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- perimeter >  65.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- bmedian >  109.50
# |   |   |   |   |   |   |   |   |   |   |--- rmean <= 137.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- rmean >  137.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- topm >  301.50
# |   |   |   |   |   |   |   |--- ratio_ell <= 1.16
# |   |   |   |   |   |   |   |   |--- bmean <= 82.48
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- bmean >  82.48
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- ratio_ell >  1.16
# |   |   |   |   |   |   |   |   |--- orien_rre <= 1.10
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- orien_rre >  1.10
# |   |   |   |   |   |   |   |   |   |--- perimeter <= 40.61
# |   |   |   |   |   |   |   |   |   |   |--- perimeter <= 35.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- perimeter >  35.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- perimeter >  40.61
# |   |   |   |   |   |   |   |   |   |   |--- extent <= 0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- extent >  0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- area >  903.75
# |   |   |   |   |   |   |--- cdmean <= 28.67
# |   |   |   |   |   |   |   |--- rmean <= 173.87
# |   |   |   |   |   |   |   |   |--- ratio_ell <= 4.34
# |   |   |   |   |   |   |   |   |   |--- gstd <= 40.65
# |   |   |   |   |   |   |   |   |   |   |--- bstd <= 18.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- bstd >  18.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- gstd >  40.65
# |   |   |   |   |   |   |   |   |   |   |--- bq25 <= 67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bq25 >  67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- ratio_ell >  4.34
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- rmean >  173.87
# |   |   |   |   |   |   |   |   |--- cdstd <= 8.43
# |   |   |   |   |   |   |   |   |   |--- perimeter <= 145.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- perimeter >  145.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- cdstd >  8.43
# |   |   |   |   |   |   |   |   |   |--- ed <= 37.28
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- ed >  37.28
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cdmean >  28.67
# |   |   |   |   |   |   |   |--- rmean <= 108.81
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- rmean >  108.81
# |   |   |   |   |   |   |   |   |--- bstd <= 36.86
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- bstd >  36.86
# |   |   |   |   |   |   |   |   |   |--- bq75 <= 178.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- bq75 >  178.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- bottomm >  327.50
# |   |   |   |   |--- bq25 <= 156.12
# |   |   |   |   |   |--- rstd <= 19.42
# |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 1.35
# |   |   |   |   |   |   |   |--- gstd <= 6.18
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- gstd >  6.18
# |   |   |   |   |   |   |   |   |--- cdstd <= 9.21
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- cdstd >  9.21
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 10.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- cdstd >  10.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- aspect_ratio_wh_s >  1.35
# |   |   |   |   |   |   |   |--- bottomm <= 373.00
# |   |   |   |   |   |   |   |   |--- gstd <= 17.99
# |   |   |   |   |   |   |   |   |   |--- area <= 1398.50
# |   |   |   |   |   |   |   |   |   |   |--- cdmean <= 17.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- cdmean >  17.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- area >  1398.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- gstd >  17.99
# |   |   |   |   |   |   |   |   |   |--- bmean <= 110.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- bmean >  110.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- bottomm >  373.00
# |   |   |   |   |   |   |   |   |--- solidity <= 0.90
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- solidity >  0.90
# |   |   |   |   |   |   |   |   |   |--- cdmean <= 3.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- cdmean >  3.84
# |   |   |   |   |   |   |   |   |   |   |--- orien_rre <= 9.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- orien_rre >  9.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- rstd >  19.42
# |   |   |   |   |   |   |--- topm <= 269.50
# |   |   |   |   |   |   |   |--- extent_s <= 0.68
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- extent_s >  0.68
# |   |   |   |   |   |   |   |   |--- bottomm <= 331.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bottomm >  331.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- topm >  269.50
# |   |   |   |   |   |   |   |--- bmedian <= 181.00
# |   |   |   |   |   |   |   |   |--- solidity <= 0.99
# |   |   |   |   |   |   |   |   |   |--- rq25 <= 92.50
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 3.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  3.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- rq25 >  92.50
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 513.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  513.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- solidity >  0.99
# |   |   |   |   |   |   |   |   |   |--- extent <= 0.91
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- extent >  0.91
# |   |   |   |   |   |   |   |   |   |   |--- rmedian <= 144.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- rmedian >  144.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- bmedian >  181.00
# |   |   |   |   |   |   |   |   |--- gq75 <= 198.50
# |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- extent_s >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 351.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  351.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- gq75 >  198.50
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 1.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- cdstd >  1.17
# |   |   |   |   |   |   |   |   |   |   |--- topm <= 298.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- topm >  298.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- bq25 >  156.12
# |   |   |   |   |   |--- rstd <= 35.38
# |   |   |   |   |   |   |--- gq75 <= 179.50
# |   |   |   |   |   |   |   |--- topm <= 342.50
# |   |   |   |   |   |   |   |   |--- gq25 <= 144.50
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- gq25 >  144.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- topm >  342.50
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- gq75 >  179.50
# |   |   |   |   |   |   |   |--- topm <= 327.00
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- topm >  327.00
# |   |   |   |   |   |   |   |   |--- perimeter <= 232.11
# |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- extent_s >  0.46
# |   |   |   |   |   |   |   |   |   |   |--- solidity <= 0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- solidity >  0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- perimeter >  232.11
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 3.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  3.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- rstd >  35.38
# |   |   |   |   |   |   |--- rq25 <= 154.38
# |   |   |   |   |   |   |   |--- gq75 <= 215.88
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- gq75 >  215.88
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- rq25 >  154.38
# |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 3.62
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- aspect_ratio_wh >  3.62
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |--- perimeter >  249.65
# |   |   |--- topm <= 304.50
# |   |   |   |--- rq25 <= 150.00
# |   |   |   |   |--- ratio_ell <= 5.24
# |   |   |   |   |   |--- solidity <= 0.65
# |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.77
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.21
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.21
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.77
# |   |   |   |   |   |   |   |--- gstd <= 45.68
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- gstd >  45.68
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- solidity >  0.65
# |   |   |   |   |   |   |--- cdmean <= 33.36
# |   |   |   |   |   |   |   |--- topm <= 251.50
# |   |   |   |   |   |   |   |   |--- bottomm <= 261.00
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 1.26
# |   |   |   |   |   |   |   |   |   |   |--- ed <= 66.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- ed >  66.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  1.26
# |   |   |   |   |   |   |   |   |   |   |--- rmean <= 94.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- rmean >  94.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- bottomm >  261.00
# |   |   |   |   |   |   |   |   |   |--- gmean <= 166.62
# |   |   |   |   |   |   |   |   |   |   |--- ed <= 462.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- ed >  462.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- gmean >  166.62
# |   |   |   |   |   |   |   |   |   |   |--- bstd <= 50.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- bstd >  50.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- topm >  251.50
# |   |   |   |   |   |   |   |   |--- bottomm <= 340.00
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 0.27
# |   |   |   |   |   |   |   |   |   |   |--- rmedian <= 125.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- rmedian >  125.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  0.27
# |   |   |   |   |   |   |   |   |   |   |--- rmean <= 165.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- rmean >  165.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- bottomm >  340.00
# |   |   |   |   |   |   |   |   |   |--- bq75 <= 114.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- bq75 >  114.50
# |   |   |   |   |   |   |   |   |   |   |--- rmedian <= 139.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- rmedian >  139.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- cdmean >  33.36
# |   |   |   |   |   |   |   |--- bq25 <= 44.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- bq25 >  44.50
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- ratio_ell >  5.24
# |   |   |   |   |   |--- extent <= 0.57
# |   |   |   |   |   |   |--- bq75 <= 142.00
# |   |   |   |   |   |   |   |--- gq75 <= 123.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- gq75 >  123.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- bq75 >  142.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- extent >  0.57
# |   |   |   |   |   |   |--- ed <= 107.02
# |   |   |   |   |   |   |   |--- orien_ell <= 179.01
# |   |   |   |   |   |   |   |   |--- cdstd <= 14.23
# |   |   |   |   |   |   |   |   |   |--- ratio_ell <= 8.57
# |   |   |   |   |   |   |   |   |   |   |--- solidity <= 0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- solidity >  0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- ratio_ell >  8.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- cdstd >  14.23
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- orien_ell >  179.01
# |   |   |   |   |   |   |   |   |--- ratio_ell <= 14.75
# |   |   |   |   |   |   |   |   |   |--- perimeter <= 444.20
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- perimeter >  444.20
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- ratio_ell >  14.75
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- ed >  107.02
# |   |   |   |   |   |   |   |--- solidity <= 0.93
# |   |   |   |   |   |   |   |   |--- bstd <= 31.38
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- bstd >  31.38
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- solidity >  0.93
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- rq25 >  150.00
# |   |   |   |   |--- ed <= 49.09
# |   |   |   |   |   |--- rq25 <= 236.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- rq25 >  236.50
# |   |   |   |   |   |   |--- extent_s <= 0.20
# |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |--- extent_s >  0.20
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- ed >  49.09
# |   |   |   |   |   |--- rstd <= 26.43
# |   |   |   |   |   |   |--- bottomm <= 127.00
# |   |   |   |   |   |   |   |--- gmean <= 207.17
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- gmean >  207.17
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |--- bottomm >  127.00
# |   |   |   |   |   |   |   |--- rmean <= 162.25
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- rmean >  162.25
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |--- rstd >  26.43
# |   |   |   |   |   |   |--- ratio_ell <= 4.76
# |   |   |   |   |   |   |   |--- orien_ell <= 79.71
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- orien_ell >  79.71
# |   |   |   |   |   |   |   |   |--- bq75 <= 203.50
# |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- bq75 >  203.50
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- ratio_ell >  4.76
# |   |   |   |   |   |   |   |--- cdmean <= 12.86
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- cdmean >  12.86
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- topm >  304.50
# |   |   |   |--- rstd <= 34.15
# |   |   |   |   |--- extent_s <= 0.12
# |   |   |   |   |   |--- bq75 <= 174.50
# |   |   |   |   |   |   |--- cdmean <= 3.12
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- cdmean >  3.12
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- bq75 >  174.50
# |   |   |   |   |   |   |--- ratio_ell <= 27.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- ratio_ell >  27.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- extent_s >  0.12
# |   |   |   |   |   |--- bottomm <= 384.50
# |   |   |   |   |   |   |--- bmean <= 142.61
# |   |   |   |   |   |   |   |--- gq75 <= 95.00
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- gq75 >  95.00
# |   |   |   |   |   |   |   |   |--- orien_ell <= 45.27
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- orien_ell >  45.27
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- bmean >  142.61
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- bottomm >  384.50
# |   |   |   |   |   |   |--- rmedian <= 235.50
# |   |   |   |   |   |   |   |--- gmedian <= 109.50
# |   |   |   |   |   |   |   |   |--- area <= 5683.75
# |   |   |   |   |   |   |   |   |   |--- rmean <= 83.36
# |   |   |   |   |   |   |   |   |   |   |--- rq75 <= 92.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- rq75 >  92.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- rmean >  83.36
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 5.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  5.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- area >  5683.75
# |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- extent_s >  0.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- gmedian >  109.50
# |   |   |   |   |   |   |   |   |--- rstd <= 33.28
# |   |   |   |   |   |   |   |   |   |--- ratio_ell <= 1.06
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- ratio_ell >  1.06
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- rstd >  33.28
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- rmedian >  235.50
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |--- rstd >  34.15
# |   |   |   |   |--- extent_s <= 0.25
# |   |   |   |   |   |--- cdmean <= 3.06
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- cdmean >  3.06
# |   |   |   |   |   |   |--- gstd <= 50.69
# |   |   |   |   |   |   |   |--- gstd <= 34.89
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- gstd >  34.89
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gstd >  50.69
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- extent_s >  0.25
# |   |   |   |   |   |--- area <= 30608.75
# |   |   |   |   |   |   |--- gmedian <= 178.50
# |   |   |   |   |   |   |   |--- cdstd <= 2.46
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cdstd >  2.46
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 0.10
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  0.10
# |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.26
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- extent_s >  0.26
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- gmedian >  178.50
# |   |   |   |   |   |   |   |--- bmedian <= 200.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- bmedian >  200.00
# |   |   |   |   |   |   |   |   |--- topm <= 426.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- topm >  426.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- area >  30608.75
# |   |   |   |   |   |   |--- class: 2

# %%
dtree2 = DecisionTreeClassifier(random_state = 2)
dtree2.fit(X_train,y_train)

y_pred = dtree.predict(X_test)
# print(y_pred)
# print(y_test)
print("Train data accuracy:",accuracy_score(y_true = y_train, y_pred = dtree.predict(X_train)))
print("Test data accuracy:",accuracy_score(y_true = y_test, y_pred = y_pred))
# Out:
# Train data accuracy: 1.0
# Test data accuracy: 0.7672764227642277

# %%
plt.figure(figsize=(25,25))
tree.plot_tree(dtree2, feature_names = column_names, fontsize=10)
plt.savefig('/home/yelhe/script/mt/output/' + 'decisiontree1' + '.jpg')
plt.show()

# %%
text_representation2 = tree.export_text(dtree2, feature_names = column_names)
print(text_representation2)
# Out:
# |--- rmedian <= 59.50
# |   |--- cdmean <= 11.80
# |   |   |--- topm <= 322.50
# |   |   |   |--- extent <= 0.79
# |   |   |   |   |--- ratio_ell <= 1.60
# |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.58
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- aspect_ratio_wh_s >  0.58
# |   |   |   |   |   |   |--- bottomm <= 297.00
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- bottomm >  297.00
# |   |   |   |   |   |   |   |--- ed <= 15.22
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- ed >  15.22
# |   |   |   |   |   |   |   |   |--- rq25 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- rq25 >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |--- ratio_ell >  1.60
# |   |   |   |   |   |--- rmean <= 45.87
# |   |   |   |   |   |   |--- bstd <= 14.42
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- bstd >  14.42
# |   |   |   |   |   |   |   |--- ed <= 27.00
# |   |   |   |   |   |   |   |   |--- bottomm <= 336.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- bottomm >  336.00
# |   |   |   |   |   |   |   |   |   |--- rmedian <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- rmedian >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- ed >  27.00
# |   |   |   |   |   |   |   |   |--- bq75 <= 68.50
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bq75 >  68.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- rmean >  45.87
# |   |   |   |   |   |   |--- ed <= 10.36
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- ed >  10.36
# |   |   |   |   |   |   |   |--- bmedian <= 62.00
# |   |   |   |   |   |   |   |   |--- rq25 <= 20.50
# |   |   |   |   |   |   |   |   |   |--- gq25 <= 21.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- gq25 >  21.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- rq25 >  20.50
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- bmedian >  62.00
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |--- extent >  0.79
# |   |   |   |   |--- aspect_ratio_wh_s <= 4.52
# |   |   |   |   |   |--- extent <= 0.87
# |   |   |   |   |   |   |--- cdmean <= 7.84
# |   |   |   |   |   |   |   |--- extent <= 0.87
# |   |   |   |   |   |   |   |   |--- rmean <= 17.46
# |   |   |   |   |   |   |   |   |   |--- rmean <= 14.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- rmean >  14.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- rmean >  17.46
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- extent >  0.87
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- cdmean >  7.84
# |   |   |   |   |   |   |   |--- bq75 <= 65.00
# |   |   |   |   |   |   |   |   |--- orien_ell <= 7.42
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- orien_ell >  7.42
# |   |   |   |   |   |   |   |   |   |--- gmedian <= 17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- gmedian >  17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- bq75 >  65.00
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- extent >  0.87
# |   |   |   |   |   |   |--- gq25 <= 47.00
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- gq25 >  47.00
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |--- aspect_ratio_wh_s >  4.52
# |   |   |   |   |   |--- class: 5
# |   |   |--- topm >  322.50
# |   |   |   |--- bq25 <= 54.50
# |   |   |   |   |--- cdmean <= 8.04
# |   |   |   |   |   |--- rq25 <= 43.00
# |   |   |   |   |   |   |--- orien_rre <= 5.24
# |   |   |   |   |   |   |   |--- orien_rre <= 4.58
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- orien_rre >  4.58
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- orien_rre >  5.24
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- rq25 >  43.00
# |   |   |   |   |   |   |--- cdmean <= 4.06
# |   |   |   |   |   |   |   |--- orien_rre <= 42.72
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- orien_rre >  42.72
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- cdmean >  4.06
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- cdmean >  8.04
# |   |   |   |   |   |--- rmedian <= 16.50
# |   |   |   |   |   |   |--- gq75 <= 37.50
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- gq75 >  37.50
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- rmedian >  16.50
# |   |   |   |   |   |   |--- rq75 <= 120.50
# |   |   |   |   |   |   |   |--- cdmean <= 8.07
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- cdmean >  8.07
# |   |   |   |   |   |   |   |   |--- ed <= 45.32
# |   |   |   |   |   |   |   |   |   |--- bottomm <= 459.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- bottomm >  459.00
# |   |   |   |   |   |   |   |   |   |   |--- bmedian <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- bmedian >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- ed >  45.32
# |   |   |   |   |   |   |   |   |   |--- orien_rre <= 44.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- orien_rre >  44.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- rq75 >  120.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- bq25 >  54.50
# |   |   |   |   |--- class: 1
# |   |--- cdmean >  11.80
# |   |   |--- gmean <= 55.40
# |   |   |   |--- bmean <= 49.63
# |   |   |   |   |--- gmean <= 33.88
# |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- gmean >  33.88
# |   |   |   |   |   |--- rmean <= 35.38
# |   |   |   |   |   |   |--- extent_s <= 0.61
# |   |   |   |   |   |   |   |--- rmean <= 32.02
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- rmean >  32.02
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- extent_s >  0.61
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- rmean >  35.38
# |   |   |   |   |   |   |--- gq25 <= 15.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- gq25 >  15.00
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.40
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.40
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |--- bmean >  49.63
# |   |   |   |   |--- orien_ell <= 176.73
# |   |   |   |   |   |--- ed <= 84.37
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- ed >  84.37
# |   |   |   |   |   |   |--- solidity <= 0.87
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- solidity >  0.87
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- orien_ell >  176.73
# |   |   |   |   |   |--- class: 5
# |   |   |--- gmean >  55.40
# |   |   |   |--- extent <= 0.79
# |   |   |   |   |--- topm <= 307.50
# |   |   |   |   |   |--- bstd <= 24.05
# |   |   |   |   |   |   |--- aspect_ratio_wh <= 1.28
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- aspect_ratio_wh >  1.28
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- bstd >  24.05
# |   |   |   |   |   |   |--- gmedian <= 35.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- gmedian >  35.50
# |   |   |   |   |   |   |   |--- gstd <= 23.32
# |   |   |   |   |   |   |   |   |--- rq25 <= 41.00
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- rq25 >  41.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gstd >  23.32
# |   |   |   |   |   |   |   |   |--- bottomm <= 226.50
# |   |   |   |   |   |   |   |   |   |--- ed <= 36.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- ed >  36.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bottomm >  226.50
# |   |   |   |   |   |   |   |   |   |--- cdmean <= 12.76
# |   |   |   |   |   |   |   |   |   |   |--- rq75 <= 67.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- rq75 >  67.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- cdmean >  12.76
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |--- topm >  307.50
# |   |   |   |   |   |--- rq75 <= 86.50
# |   |   |   |   |   |   |--- gq75 <= 71.88
# |   |   |   |   |   |   |   |--- ratio_ell <= 3.79
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- ratio_ell >  3.79
# |   |   |   |   |   |   |   |   |--- extent_s <= 0.40
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- extent_s >  0.40
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- gq75 >  71.88
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.55
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.55
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 7.18
# |   |   |   |   |   |   |   |   |   |--- topm <= 409.50
# |   |   |   |   |   |   |   |   |   |   |--- rq25 <= 40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- rq25 >  40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- topm >  409.50
# |   |   |   |   |   |   |   |   |   |   |--- rq75 <= 57.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- rq75 >  57.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  7.18
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- rq75 >  86.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |--- extent >  0.79
# |   |   |   |   |--- rq75 <= 64.38
# |   |   |   |   |   |--- area <= 295.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- area >  295.50
# |   |   |   |   |   |   |--- extent <= 0.88
# |   |   |   |   |   |   |   |--- solidity <= 0.91
# |   |   |   |   |   |   |   |   |--- bstd <= 34.72
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- bstd >  34.72
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- solidity >  0.91
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- extent >  0.88
# |   |   |   |   |   |   |   |--- ratio_ell <= 2.52
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- ratio_ell >  2.52
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |--- rq75 >  64.38
# |   |   |   |   |   |--- ratio_ell <= 1.10
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- ratio_ell >  1.10
# |   |   |   |   |   |   |--- cdmean <= 22.57
# |   |   |   |   |   |   |   |--- gq75 <= 82.62
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gq75 >  82.62
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- cdmean >  22.57
# |   |   |   |   |   |   |   |--- bmean <= 89.23
# |   |   |   |   |   |   |   |   |--- gmean <= 75.75
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- gmean >  75.75
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- bmean >  89.23
# |   |   |   |   |   |   |   |   |--- gmean <= 72.16
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- gmean >  72.16
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |--- rmedian >  59.50
# |   |--- perimeter <= 232.86
# |   |   |--- extent_s <= 0.44
# |   |   |   |--- bq75 <= 139.75
# |   |   |   |   |--- rstd <= 47.25
# |   |   |   |   |   |--- gq75 <= 84.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gq75 >  84.00
# |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 1.96
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- aspect_ratio_wh_s >  1.96
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 2.15
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  2.15
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- rstd >  47.25
# |   |   |   |   |   |--- bmedian <= 89.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- bmedian >  89.00
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |--- bq75 >  139.75
# |   |   |   |   |--- bottomm <= 322.00
# |   |   |   |   |   |--- extent_s <= 0.24
# |   |   |   |   |   |   |--- cdstd <= 8.95
# |   |   |   |   |   |   |   |--- extent <= 0.24
# |   |   |   |   |   |   |   |   |--- bmean <= 160.26
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- bmean >  160.26
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- extent >  0.24
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- cdstd >  8.95
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- extent_s >  0.24
# |   |   |   |   |   |   |--- bq75 <= 235.00
# |   |   |   |   |   |   |   |--- gmedian <= 97.25
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- gmedian >  97.25
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- bq75 >  235.00
# |   |   |   |   |   |   |   |--- rmean <= 209.74
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- rmean >  209.74
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- bottomm >  322.00
# |   |   |   |   |   |--- orien_rre <= 8.44
# |   |   |   |   |   |   |--- rq75 <= 191.50
# |   |   |   |   |   |   |   |--- gstd <= 43.61
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- gstd >  43.61
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- rq75 >  191.50
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- orien_rre >  8.44
# |   |   |   |   |   |   |--- ratio_ell <= 18.18
# |   |   |   |   |   |   |   |--- rmedian <= 91.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- rmedian >  91.00
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 0.08
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  0.08
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 0.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- cdstd >  0.70
# |   |   |   |   |   |   |   |   |   |   |--- bstd <= 45.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- bstd >  45.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- ratio_ell >  18.18
# |   |   |   |   |   |   |   |--- gq25 <= 151.12
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- gq25 >  151.12
# |   |   |   |   |   |   |   |   |--- rq25 <= 159.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- rq25 >  159.00
# |   |   |   |   |   |   |   |   |   |--- area <= 773.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- area >  773.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- extent_s >  0.44
# |   |   |   |--- bottomm <= 327.50
# |   |   |   |   |--- bottomm <= 284.50
# |   |   |   |   |   |--- solidity <= 0.93
# |   |   |   |   |   |   |--- rq25 <= 189.12
# |   |   |   |   |   |   |   |--- rstd <= 41.84
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 5.27
# |   |   |   |   |   |   |   |   |   |--- ratio_ell <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- ratio_ell >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 93.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  93.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  5.27
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- rstd >  41.84
# |   |   |   |   |   |   |   |   |--- orien_rre <= 24.52
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- orien_rre >  24.52
# |   |   |   |   |   |   |   |   |   |--- bstd <= 61.37
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- bstd >  61.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- rq25 >  189.12
# |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 2.18
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |--- aspect_ratio_wh >  2.18
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- solidity >  0.93
# |   |   |   |   |   |   |--- extent_s <= 0.84
# |   |   |   |   |   |   |   |--- ratio_ell <= 1.11
# |   |   |   |   |   |   |   |   |--- rstd <= 31.09
# |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- rstd >  31.09
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- ratio_ell >  1.11
# |   |   |   |   |   |   |   |   |--- rmedian <= 129.25
# |   |   |   |   |   |   |   |   |   |--- rq75 <= 152.00
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 86.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  86.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- rq75 >  152.00
# |   |   |   |   |   |   |   |   |   |   |--- orien_ell <= 38.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- orien_ell >  38.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- rmedian >  129.25
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 4.48
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 52.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  52.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  4.48
# |   |   |   |   |   |   |   |   |   |   |--- bq25 <= 142.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- bq25 >  142.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- extent_s >  0.84
# |   |   |   |   |   |   |   |--- bq25 <= 136.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- bq25 >  136.50
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |--- bottomm >  284.50
# |   |   |   |   |   |--- ed <= 22.85
# |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 0.24
# |   |   |   |   |   |   |   |--- orien_ell <= 179.96
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- orien_ell >  179.96
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- aspect_ratio_wh_s >  0.24
# |   |   |   |   |   |   |   |--- perimeter <= 31.36
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- perimeter >  31.36
# |   |   |   |   |   |   |   |   |--- area <= 189.25
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 9.02
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 291.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  291.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- cdstd >  9.02
# |   |   |   |   |   |   |   |   |   |   |--- perimeter <= 57.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- perimeter >  57.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- area >  189.25
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 2.05
# |   |   |   |   |   |   |   |   |   |   |--- bmean <= 131.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- bmean >  131.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  2.05
# |   |   |   |   |   |   |   |   |   |   |--- extent <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- extent >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- ed >  22.85
# |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 2.55
# |   |   |   |   |   |   |   |--- rmedian <= 90.50
# |   |   |   |   |   |   |   |   |--- gmean <= 96.91
# |   |   |   |   |   |   |   |   |   |--- bmedian <= 71.50
# |   |   |   |   |   |   |   |   |   |   |--- cdstd <= 3.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- cdstd >  3.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- bmedian >  71.50
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 7.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  7.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- gmean >  96.91
# |   |   |   |   |   |   |   |   |   |--- extent <= 0.88
# |   |   |   |   |   |   |   |   |   |   |--- orien_rre <= 3.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- orien_rre >  3.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- extent >  0.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- rmedian >  90.50
# |   |   |   |   |   |   |   |   |--- cdmean <= 28.64
# |   |   |   |   |   |   |   |   |   |--- rq25 <= 147.12
# |   |   |   |   |   |   |   |   |   |   |--- rq25 <= 72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- rq25 >  72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- rq25 >  147.12
# |   |   |   |   |   |   |   |   |   |   |--- rstd <= 33.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- rstd >  33.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- cdmean >  28.64
# |   |   |   |   |   |   |   |   |   |--- cdmean <= 41.61
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- cdmean >  41.61
# |   |   |   |   |   |   |   |   |   |   |--- orien_ell <= 65.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- orien_ell >  65.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- aspect_ratio_wh_s >  2.55
# |   |   |   |   |   |   |   |--- orien_ell <= 100.97
# |   |   |   |   |   |   |   |   |--- cdmean <= 20.51
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- cdmean >  20.51
# |   |   |   |   |   |   |   |   |   |--- rmean <= 94.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- rmean >  94.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- orien_ell >  100.97
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- bottomm >  327.50
# |   |   |   |   |--- bq25 <= 158.62
# |   |   |   |   |   |--- rstd <= 16.87
# |   |   |   |   |   |   |--- orien_rre <= 78.55
# |   |   |   |   |   |   |   |--- ratio_ell <= 2.11
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- ratio_ell >  2.11
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 3.27
# |   |   |   |   |   |   |   |   |   |--- orien_ell <= 31.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- orien_ell >  31.21
# |   |   |   |   |   |   |   |   |   |   |--- solidity <= 0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- solidity >  0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  3.27
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- orien_rre >  78.55
# |   |   |   |   |   |   |   |--- perimeter <= 61.63
# |   |   |   |   |   |   |   |   |--- gq75 <= 108.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- gq75 >  108.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- perimeter >  61.63
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- rstd >  16.87
# |   |   |   |   |   |   |--- topm <= 269.50
# |   |   |   |   |   |   |   |--- bstd <= 38.17
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- bstd >  38.17
# |   |   |   |   |   |   |   |   |--- rstd <= 45.63
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- rstd >  45.63
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- topm >  269.50
# |   |   |   |   |   |   |   |--- gq25 <= 97.75
# |   |   |   |   |   |   |   |   |--- cdmean <= 17.33
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 0.70
# |   |   |   |   |   |   |   |   |   |   |--- topm <= 490.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- topm >  490.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- cdstd >  0.70
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh <= 11.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh >  11.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- cdmean >  17.33
# |   |   |   |   |   |   |   |   |   |--- perimeter <= 46.51
# |   |   |   |   |   |   |   |   |   |   |--- extent <= 0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- extent >  0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- perimeter >  46.51
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 333.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  333.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- gq25 >  97.75
# |   |   |   |   |   |   |   |   |--- rq75 <= 99.50
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- rq75 >  99.50
# |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- extent_s >  0.46
# |   |   |   |   |   |   |   |   |   |   |--- gstd <= 15.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- gstd >  15.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |--- bq25 >  158.62
# |   |   |   |   |   |--- extent_s <= 0.67
# |   |   |   |   |   |   |--- cdmean <= 6.54
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- cdmean >  6.54
# |   |   |   |   |   |   |   |--- topm <= 327.00
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- topm >  327.00
# |   |   |   |   |   |   |   |   |--- extent_s <= 0.49
# |   |   |   |   |   |   |   |   |   |--- area <= 519.50
# |   |   |   |   |   |   |   |   |   |   |--- bq25 <= 180.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- bq25 >  180.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- area >  519.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- extent_s >  0.49
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- extent_s >  0.67
# |   |   |   |   |   |   |--- rstd <= 14.60
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- rstd >  14.60
# |   |   |   |   |   |   |   |--- area <= 146.50
# |   |   |   |   |   |   |   |   |--- gstd <= 40.71
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- gstd >  40.71
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- area >  146.50
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |--- perimeter >  232.86
# |   |   |--- topm <= 305.50
# |   |   |   |--- rq25 <= 150.00
# |   |   |   |   |--- ratio_ell <= 3.55
# |   |   |   |   |   |--- extent_s <= 0.59
# |   |   |   |   |   |   |--- bq25 <= 66.50
# |   |   |   |   |   |   |   |--- bstd <= 59.18
# |   |   |   |   |   |   |   |   |--- gmedian <= 68.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- gmedian >  68.00
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- bstd >  59.18
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- bq25 >  66.50
# |   |   |   |   |   |   |   |--- solidity <= 0.32
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- solidity >  0.32
# |   |   |   |   |   |   |   |   |--- solidity <= 0.83
# |   |   |   |   |   |   |   |   |   |--- gq75 <= 112.00
# |   |   |   |   |   |   |   |   |   |   |--- cdstd <= 8.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- cdstd >  8.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- gq75 >  112.00
# |   |   |   |   |   |   |   |   |   |   |--- topm <= 266.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- topm >  266.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- solidity >  0.83
# |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.52
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- extent_s >  0.52
# |   |   |   |   |   |   |   |   |   |   |--- extent <= 0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- extent >  0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- extent_s >  0.59
# |   |   |   |   |   |   |--- topm <= 278.00
# |   |   |   |   |   |   |   |--- bottomm <= 259.50
# |   |   |   |   |   |   |   |   |--- extent <= 0.79
# |   |   |   |   |   |   |   |   |   |--- cdstd <= 11.42
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- cdstd >  11.42
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- extent >  0.79
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- bottomm >  259.50
# |   |   |   |   |   |   |   |   |--- rstd <= 73.34
# |   |   |   |   |   |   |   |   |   |--- cdmean <= 33.47
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 2.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- aspect_ratio_wh_s >  2.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- cdmean >  33.47
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- rstd >  73.34
# |   |   |   |   |   |   |   |   |   |--- ratio_ell <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- ratio_ell >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- topm >  278.00
# |   |   |   |   |   |   |   |--- rq75 <= 112.00
# |   |   |   |   |   |   |   |   |--- bottomm <= 480.50
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- bottomm >  480.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- rq75 >  112.00
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- ratio_ell >  3.55
# |   |   |   |   |   |--- ed <= 162.29
# |   |   |   |   |   |   |--- solidity <= 0.72
# |   |   |   |   |   |   |   |--- ratio_ell <= 4.56
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- ratio_ell >  4.56
# |   |   |   |   |   |   |   |   |--- area <= 439.25
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- area >  439.25
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- solidity >  0.72
# |   |   |   |   |   |   |   |--- rmedian <= 64.00
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- rmedian >  64.00
# |   |   |   |   |   |   |   |   |--- extent <= 0.48
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- extent >  0.48
# |   |   |   |   |   |   |   |   |   |--- gmedian <= 210.50
# |   |   |   |   |   |   |   |   |   |   |--- extent_s <= 0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- extent_s >  0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- gmedian >  210.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- ed >  162.29
# |   |   |   |   |   |   |--- extent <= 0.66
# |   |   |   |   |   |   |   |--- bq25 <= 78.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- bq25 >  78.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- extent >  0.66
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- rq25 >  150.00
# |   |   |   |   |--- ed <= 51.08
# |   |   |   |   |   |--- bstd <= 9.09
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- bstd >  9.09
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- ed >  51.08
# |   |   |   |   |   |--- rstd <= 26.51
# |   |   |   |   |   |   |--- bq75 <= 146.50
# |   |   |   |   |   |   |   |--- orien_ell <= 78.31
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |--- orien_ell >  78.31
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- bq75 >  146.50
# |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |--- rstd >  26.51
# |   |   |   |   |   |   |--- aspect_ratio_wh <= 0.25
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- aspect_ratio_wh >  0.25
# |   |   |   |   |   |   |   |--- cdstd <= 10.79
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cdstd >  10.79
# |   |   |   |   |   |   |   |   |--- gmean <= 191.65
# |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- gmean >  191.65
# |   |   |   |   |   |   |   |   |   |--- gstd <= 34.61
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- gstd >  34.61
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |--- topm >  305.50
# |   |   |   |--- rstd <= 33.12
# |   |   |   |   |--- extent_s <= 0.12
# |   |   |   |   |   |--- extent <= 0.60
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- extent >  0.60
# |   |   |   |   |   |   |--- orien_rre <= 27.89
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- orien_rre >  27.89
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- extent_s >  0.12
# |   |   |   |   |   |--- ed <= 85.06
# |   |   |   |   |   |   |--- bq25 <= 141.50
# |   |   |   |   |   |   |   |--- rq25 <= 71.50
# |   |   |   |   |   |   |   |   |--- rq25 <= 54.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- rq25 >  54.00
# |   |   |   |   |   |   |   |   |   |--- bottomm <= 525.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- bottomm >  525.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- rq25 >  71.50
# |   |   |   |   |   |   |   |   |--- cdmean <= 9.46
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- cdmean >  9.46
# |   |   |   |   |   |   |   |   |   |--- topm <= 340.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- topm >  340.00
# |   |   |   |   |   |   |   |   |   |   |--- gmean <= 103.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- gmean >  103.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- bq25 >  141.50
# |   |   |   |   |   |   |   |--- cdstd <= 1.55
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- cdstd >  1.55
# |   |   |   |   |   |   |   |   |--- gstd <= 31.03
# |   |   |   |   |   |   |   |   |   |--- rstd <= 27.59
# |   |   |   |   |   |   |   |   |   |   |--- cdstd <= 2.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- cdstd >  2.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- rstd >  27.59
# |   |   |   |   |   |   |   |   |   |   |--- bottomm <= 458.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- bottomm >  458.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- gstd >  31.03
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- ed >  85.06
# |   |   |   |   |   |   |--- rq25 <= 197.50
# |   |   |   |   |   |   |   |--- topm <= 491.00
# |   |   |   |   |   |   |   |   |--- extent_s <= 0.20
# |   |   |   |   |   |   |   |   |   |--- orien_rre <= 32.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- orien_rre >  32.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- extent_s >  0.20
# |   |   |   |   |   |   |   |   |   |--- solidity <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- solidity >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- solidity <= 0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- solidity >  0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- topm >  491.00
# |   |   |   |   |   |   |   |   |--- gmedian <= 148.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- gmedian >  148.00
# |   |   |   |   |   |   |   |   |   |--- rmean <= 150.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- rmean >  150.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- rq25 >  197.50
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |--- rstd >  33.12
# |   |   |   |   |--- extent_s <= 0.15
# |   |   |   |   |   |--- rq75 <= 200.50
# |   |   |   |   |   |   |--- aspect_ratio_wh_s <= 4.19
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- aspect_ratio_wh_s >  4.19
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- rq75 >  200.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- extent_s >  0.15
# |   |   |   |   |   |--- cdstd <= 2.57
# |   |   |   |   |   |   |--- cdstd <= 2.45
# |   |   |   |   |   |   |   |--- rmedian <= 170.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- rmedian >  170.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- cdstd >  2.45
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- cdstd >  2.57
# |   |   |   |   |   |   |--- gmedian <= 178.50
# |   |   |   |   |   |   |   |--- ed <= 258.94
# |   |   |   |   |   |   |   |   |--- ratio_ell <= 30.38
# |   |   |   |   |   |   |   |   |   |--- extent <= 0.87
# |   |   |   |   |   |   |   |   |   |   |--- rstd <= 34.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- rstd >  34.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- extent >  0.87
# |   |   |   |   |   |   |   |   |   |   |--- rstd <= 36.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |   |--- rstd >  36.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- ratio_ell >  30.38
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- ed >  258.94
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- gmedian >  178.50
# |   |   |   |   |   |   |   |--- solidity <= 0.87
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- solidity >  0.87
# |   |   |   |   |   |   |   |   |--- class: 2

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)
cm_display.plot()

# %%
dtree.classes_
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
print(f'class 0 accuracy: {confusion_matrix[0][0]/sum(confusion_matrix[0])}')
print(f'class 1 accuracy: {confusion_matrix[1][1]/sum(confusion_matrix[1])}')
print(f'class 2 accuracy: {confusion_matrix[2][2]/sum(confusion_matrix[2])}')
print(f'class 3 accuracy: {confusion_matrix[3][3]/sum(confusion_matrix[3])}')
print(f'class 4 accuracy: {confusion_matrix[4][4]/sum(confusion_matrix[4])}')
print(f'class 5 accuracy: {confusion_matrix[5][5]/sum(confusion_matrix[5])}')
# Out:
# class 0 accuracy: 0.6923076923076923
# class 1 accuracy: 0.36363636363636365
# class 2 accuracy: 0.7016574585635359
# class 3 accuracy: 0.8273092369477911
# class 4 accuracy: 0.8461538461538461
# class 5 accuracy: 0.7195121951219512

# %% [markdown]
# ### Linear Regression

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, 
                                                    test_size = 0.30, 
                                                    random_state = 3)

reg = linear_model.LinearRegression()
reg.fit(X_train2, y_train2)

y_pred_lr = reg.predict(X_test2)


print('Coefficients: ', reg.coef_)
print('Variance score: {}'.format(reg.score(X_test2, y_test2)))

# # plot for residual error
# # # plt.style.use('fivethirtyeight')
# # plotting residual errors in training data
# plt.scatter(reg.predict(X_train2),
# 			reg.predict(X_train2) - y_train2,
# 			color="green", s=10,
# 			label='Train data')
# # plotting residual errors in test data
# plt.scatter(reg.predict(X_test2),
# 			reg.predict(X_test2) - y_test2,
# 			color="blue", s=10,
# 			label='Test data')
# plt.hlines(y=0, xmin=0, xmax=50, linewidth=2)
# plt.legend(loc='upper right')
# plt.title("Residual errors")
# plt.show()
# plt.clf()
# plt.close()
# Out:
# Coefficients:  [ 1.16543889e-03 -3.71461096e-02  1.17803314e-02  9.99061772e-02
#   5.50473862e-02 -8.93141340e-02 -8.75457795e-04  2.00175112e-02
#  -2.14234538e-02 -4.70982637e-02 -6.81869747e-03  6.58133235e-03
#  -4.24472612e-02  2.18727951e-02  2.28928616e-02  1.01666184e-02
#  -5.28127868e-03  1.53120094e-05 -1.43509451e-02  8.22996034e-01
#   7.28469129e-01 -1.87667894e-02 -2.21402115e+00 -8.87512284e-04
#   3.70366829e-04 -9.76111465e-03 -4.55868795e-03  1.36314679e-03
#   4.10840333e-03 -4.34256082e-03]
# Variance score: 0.3415139439723285

# %%
# from sklearn.preprocessing import PolynomialFeatures
# poly_reg2=PolynomialFeatures(degree=2)
# X_poly = poly_reg2.fit_transform(X)
# lin_reg_2 = linear_model.LinearRegression()
# lin_reg_2.fit(X_poly,y)
# y_pred_lr2 = lin_reg_2.predict(X_test)

# poly_reg3 = PolynomialFeatures(degree=3)
# X_poly3=poly_reg3.fit_transform(X)
# lin_reg_3=linear_model.LinearRegression()
# lin_reg_3.fit(X_poly3,y)
# y_pred_lr3 = lin_reg_3.predict(X_test)

# # plot for residual error
# plt.style.use('fivethirtyeight')
# # plotting residual errors in training data
# plt.scatter(lin_reg_2.predict(X_train),
# 			lin_reg_2.predict(X_train) - y_train,
# 			color="green", s=10,
# 			label='Train data')
# # plotting residual errors in test data
# plt.scatter(lin_reg_2.predict(X_test),
# 			lin_reg_2.predict(X_test) - y_test,
# 			color="blue", s=10,
# 			label='Test data')
# plt.hlines(y=0, xmin=0, xmax=50, linewidth=2)
# plt.legend(loc='upper right')
# plt.title("Residual errors")
# plt.show()

# %% [markdown]
# ### KNN

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, 
                                                    test_size = 0.25, 
                                                    random_state = 6)

neigh = KNeighborsClassifier(n_neighbors = 9)
neigh.fit(X_train1.values, y_train1)
y_pred_knn = neigh.predict(X_test1.values)

# %%
# print(y_pred_knn)
# print(y_test1)
print("Train data accuracy:",accuracy_score(y_true = y_train1, y_pred = neigh.predict(X_train1.values)))
print("Test data accuracy:",accuracy_score(y_true = y_test1, y_pred = y_pred_knn))
# Out:
# Train data accuracy: 0.7298305084745763
# Test data accuracy: 0.6148373983739838

# %%
confusion_matrix_knn = metrics.confusion_matrix(y_test1, y_pred_knn)
print(confusion_matrix_knn)
cm_display_knn = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_knn)
cm_display_knn.plot()
# Out:
# [[ 40   0   7  32   1  16]
#  [  1   1  11   4   0   0]
#  [ 15   0  79  64   5   3]
#  [ 35   0  23 393   0  50]
#  [  8   0  12   4   8   0]
#  [ 22   0   4  61   1  84]]

# %%
print(f'class 0 accuracy: {confusion_matrix_knn[0][0]/sum(confusion_matrix_knn[0])}')
print(f'class 1 accuracy: {confusion_matrix_knn[1][1]/sum(confusion_matrix_knn[1])}')
print(f'class 2 accuracy: {confusion_matrix_knn[2][2]/sum(confusion_matrix_knn[2])}')
print(f'class 3 accuracy: {confusion_matrix_knn[3][3]/sum(confusion_matrix_knn[3])}')
print(f'class 4 accuracy: {confusion_matrix_knn[4][4]/sum(confusion_matrix_knn[4])}')
print(f'class 5 accuracy: {confusion_matrix_knn[5][5]/sum(confusion_matrix_knn[5])}')
# Out:
# class 0 accuracy: 0.4166666666666667
# class 1 accuracy: 0.058823529411764705
# class 2 accuracy: 0.4759036144578313
# class 3 accuracy: 0.7844311377245509
# class 4 accuracy: 0.25
# class 5 accuracy: 0.4883720930232558

# %% [markdown]
# ### Random Forest

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X, y, 
                                                    test_size = 0.25, 
                                                    random_state = 7)
X_train3.shape, X_test3.shape
# Out:
# ((2950, 30), (984, 30))

# %%
rf = RandomForestClassifier(n_estimators = 6, random_state = 7)
rf.fit(X_train3, y_train3)
y_pred_rf = rf.predict(X_test3)

# %%
# print(y_pred_rf)
# print(y_test3)
print("Train data accuracy:",accuracy_score(y_true = y_train3, y_pred = rf.predict(X_train3)))
print("Test data accuracy:",accuracy_score(y_true = y_test3, y_pred = y_pred_rf))
# Out:
# Train data accuracy: 0.9813559322033898
# Test data accuracy: 0.8008130081300813

# %%
confusion_matrix_rf = metrics.confusion_matrix(y_test3, y_pred_rf)
print(confusion_matrix_rf)
cm_display_rf = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_rf)
cm_display_rf.plot()
# Out:
# [[ 72   0   0  21   0   4]
#  [  0   4   1   1   0   0]
#  [  3   0 134  23   0   0]
#  [ 22   3  36 436   1  12]
#  [  0   0   0   4  21   0]
#  [  9   0   3  53   0 121]]

# %%
print(f'class 0 accuracy: {confusion_matrix_rf[0][0]/sum(confusion_matrix_rf[0])}')
print(f'class 1 accuracy: {confusion_matrix_rf[1][1]/sum(confusion_matrix_rf[1])}')
print(f'class 2 accuracy: {confusion_matrix_rf[2][2]/sum(confusion_matrix_rf[2])}')
print(f'class 3 accuracy: {confusion_matrix_rf[3][3]/sum(confusion_matrix_rf[3])}')
print(f'class 4 accuracy: {confusion_matrix_rf[4][4]/sum(confusion_matrix_rf[4])}')
print(f'class 5 accuracy: {confusion_matrix_knn[5][5]/sum(confusion_matrix_knn[5])}')
# Out:
# class 0 accuracy: 0.7422680412371134
# class 1 accuracy: 0.6666666666666666
# class 2 accuracy: 0.8375
# class 3 accuracy: 0.8549019607843137
# class 4 accuracy: 0.84
# class 5 accuracy: 0.4883720930232558

# %%
feature_name = list(dfc.columns.values.tolist())
importances = rf.feature_importances_
df_rf = pd.DataFrame({'features':feature_name, 'importances':importances})
df_rf.sort_values(by = ['importances'], ascending = False, inplace = True)
sn.barplot(x = df_rf['importances'], y = df_rf['features'])
plt.xlabel('importance')
plt.ylabel('feature')
# Out:
# Text(0, 0.5, 'feature')

# %% [markdown]
# ### SVM

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(X, y, 
                                                    test_size = 0.3, 
                                                    random_state = 9)
X_train4.shape, X_test4.shape
# Out:
# ((2753, 30), (1181, 30))

# %%
svmm = svm.SVC(random_state = 9, decision_function_shape = 'ovo')
svmm.fit(X_train4, y_train4)
y_pred_svm = svmm.predict(X_test4)

# %%
# print(y_pred_svm)
# print(y_test4)
print(svmm.classes_)
print("Train data accuracy:",accuracy_score(y_true = y_train4, y_pred = svmm.predict(X_train4)))
print("Test data accuracy:",accuracy_score(y_true = y_test4, y_pred = y_pred_svm))
print("Precision:",metrics.precision_score(y_true = y_test4, y_pred = y_pred_svm, 
                                           average = 'micro'))
print("Recall:",metrics.recall_score(y_true = y_test4, y_pred = y_pred_svm,
                                    average = 'micro'))
# Out:
# [0 1 2 3 4 5]
# Train data accuracy: 0.5430439520523066
# Test data accuracy: 0.5580016934801016
# Precision: 0.5580016934801016
# Recall: 0.5580016934801016

# %%
confusion_matrix_svm = metrics.confusion_matrix(y_test4, y_pred_svm)
print(confusion_matrix_svm)
cm_display_svm = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_svm)
cm_display_svm.plot()
# Out:
# [[ 23   0  12  91   0   0]
#  [  0   0   0  15   0   0]
#  [  8   0  30 164   0   0]
#  [  2   0   1 606   0   0]
#  [  5   0  21  10   0   0]
#  [  5   0   3 185   0   0]]

# %%
print(f'class 0 accuracy: {confusion_matrix_svm[0][0]/sum(confusion_matrix_svm[0])}')
print(f'class 1 accuracy: {confusion_matrix_svm[1][1]/sum(confusion_matrix_svm[1])}')
print(f'class 2 accuracy: {confusion_matrix_svm[2][2]/sum(confusion_matrix_svm[2])}')
print(f'class 3 accuracy: {confusion_matrix_svm[3][3]/sum(confusion_matrix_svm[3])}')
print(f'class 4 accuracy: {confusion_matrix_svm[4][4]/sum(confusion_matrix_svm[4])}')
print(f'class 5 accuracy: {confusion_matrix_knn[5][5]/sum(confusion_matrix_knn[5])}')
# Out:
# class 0 accuracy: 0.18253968253968253
# class 1 accuracy: 0.0
# class 2 accuracy: 0.1485148514851485
# class 3 accuracy: 0.9950738916256158
# class 4 accuracy: 0.0
# class 5 accuracy: 0.4883720930232558

# %% [markdown]
# ### Correlation Matrix

# %%
corr_matrix = dfc.corr()
plt.figure(figsize=(20,20))
sn.set(font_scale = 0.8)
sn.heatmap(corr_matrix, annot = True, )
# plt.savefig('fig06_corrmat.png')
plt.show()
