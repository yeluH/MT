# %%
import torch
torch.cuda.empty_cache()

# %%
import os 
os.environ['MPLCONFIGDIR'] = os.getcwd() + "/configs/"
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import cv2
import urllib.request
from PIL import Image

# %%
import pandas as pd
import pyproj

# %%
import os 
os.environ['MPLCONFIGDIR'] = os.getcwd() + "/configs/"
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
from pathlib import Path

# %%
import joblib

# %%
from mt_function_yl import *

# %%
import seaborn as sn

# %%
from scipy import stats

# %%
from tabulate import tabulate

# %%
import statsmodels.api as sm

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.cluster import HDBSCAN
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve

from sklearn import linear_model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import LabelEncoder

from sklearn import svm

import seaborn as sn


# For regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import PredictionErrorDisplay

# %% [markdown]
# ### Data loading

# %%
aa = pd.read_csv('/home/yelhe/script/mt/dataraw/dfaa.csv')

# %%
acv = pd.read_csv('/home/yelhe/script/mt/model/allvariable_accident.csv')
rpv = pd.read_csv('/home/yelhe/script/mt/model/allvariable_rp.csv')

# %%
# personal injusry presence
acv = acv.assign(inp = 1)
acv.loc[(acv['SV'] == 0) & (acv['LV'] == 0), 'inp'] = 0

# %%
acv.head()
# Out:
#                Nr  cp        ie     iemin     iemax       mew    mewmin  \
# 0  99900060852597   1 -0.657370 -0.217311 -0.913935  2.465985  1.418306
# 1  99900063018611   1 -0.791117 -0.772531 -0.935720 -0.314871 -0.046518
# 2  99900052723510   1  1.408380  1.435020  1.205968  2.371130  2.407072
# 3  99900061514043   1 -0.237414 -1.149421  0.417812  0.840529  1.299824
# 4  99900063037843   1  1.189897  1.324371  1.018182  1.043759  0.385839
#
#      mewmax       meg    megmin  ...  speedlimit_4  speedlimit_5  \
# 0  3.290652  0.805937  0.700286  ...             0             0
# 1  0.005271  2.190198  2.415219  ...             0             0
# 2  1.751330  0.121938  0.807164  ...             0             0
# 3  0.226998 -0.669668 -0.046474  ...             0             0
# 4  1.337648  0.399470 -0.423856  ...             0             0
#
#    speedlimit_6  SV  LV    pd  svp  lvp  pdp  inp
# 0             0   0   1    15    0    1    1    1
# 1             0   1   0     0    1    0    0    1
# 2             0   0   1   500    0    1    1    1
# 3             0   0   1  3000    0    1    1    1
# 4             0   1   0   200    1    0    1    1
#
# [5 rows x 116 columns]

# %%
acv.groupby(['svp']).size()
# Out:
# svp
# 0    246
# 1     49
# dtype: int64

# %%
acv.groupby(['lvp']).size()
# Out:
# lvp
# 0     83
# 1    212
# dtype: int64

# %%
acv.groupby(['inp']).size()
# Out:
# inp
# 0     40
# 1    255
# dtype: int64

# %%
acv.groupby(['pdp']).size()
# Out:
# pdp
# 0    146
# 1    149
# dtype: int64

# %% [markdown]
# ### Regression

# %%
cn = ['cp', 'ie', 'iemin', 'iemax', 'mew', 'mewmin', 'mewmax', 'meg', 
      'megmin', 'megmax', 'cmean', 'cmin', 'cmax', 'dbusl', 'dtraml', 
      'dtrainl', 'dplight', 'dstation', 'dparkcar', 'dparktw', 'dpedcro', 'dstopsign', 'dcurb',
      'dtrafficarea', 'droad', 'droad_sl', 'dvfpath', 'gvm_dwv', 'gvm_msp', 'gvm_asp', 'r_width_value',
      'speedlimit_value', 'curbtype_1', 'curbtype_2', 'z_qnr_1', 'z_qnr_2', 'z_qnr_3', 'z_qnr_4', 'z_qnr_5',
      'z_qnr_6', 'z_qnr_7', 'z_qnr_8', 'z_qnr_9', 'z_qnr_10', 'z_qnr_11', 'z_qnr_12', 'z_qnr_13',
      'z_qnr_14', 'z_qnr_15', 'z_qnr_16', 'z_qnr_17', 'z_qnr_18',
      'z_qnr_19', 'z_qnr_20', 'z_qnr_21', 'z_qnr_22', 'z_qnr_23', 'z_qnr_24',
       'z_qnr_25', 'z_qnr_26', 'z_qnr_27', 'z_qnr_28', 'z_qnr_29', 'z_qnr_30',
       'z_qnr_31', 'z_qnr_32', 'z_qnr_33', 'z_knr_1', 'z_knr_2', 'z_knr_3',
       'z_knr_4', 'z_knr_5', 'z_knr_6', 'z_knr_7', 'z_knr_8', 'z_knr_9',
       'z_knr_10', 'z_knr_11', 'z_knr_12', 'trafficarea_1', 'trafficarea_2',
       'trafficarea_3', 'r_width_1', 'r_width_2', 'r_width_3', 'r_width_4',
       'r_width_5', 'r_width_6', 'r_width_7', 'r_surface_1', 'r_surface_2',
       'speedlimit_1', 'speedlimit_2', 'speedlimit_3', 'speedlimit_4',
       'speedlimit_5', 'speedlimit_6',
       'bicyclecount', 'carcount',
       'd_bicyclecount','d_carcount']

# %%
len(cn)
# Out:
# 101

# %%
acv.shape
# Out:
# (295, 116)

# %%
acv.columns
# Out:
# Index(['Nr', 'cp', 'ie', 'iemin', 'iemax', 'mew', 'mewmin', 'mewmax', 'meg',
#        'megmin',
#        ...
#        'speedlimit_4', 'speedlimit_5', 'speedlimit_6', 'SV', 'LV', 'pd', 'svp',
#        'lvp', 'pdp', 'inp'],
#       dtype='object', length=116)

# %%
y1 = acv['svp']
x = acv[cn]
x = sm.add_constant(x)
model1 = sm.OLS(y1, x)
result1 = model1.fit()
result1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    svp   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     1.162
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):              0.201
# Time:                        03:06:38   Log-Likelihood:                -75.343
# No. Observations:                 295   AIC:                             308.7
# Df Residuals:                     216   BIC:                             600.0
# Df Model:                          78
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# cp                  -0.1168      0.222     -0.525      0.600      -0.555       0.321
# ie                   0.3761      0.220      1.707      0.089      -0.058       0.810
# iemin               -0.1795      0.136     -1.321      0.188      -0.447       0.088
# iemax               -0.2136      0.111     -1.920      0.056      -0.433       0.006
# mew                 -0.0911      0.121     -0.755      0.451      -0.329       0.147
# mewmin               0.0638      0.080      0.794      0.428      -0.095       0.222
# mewmax              -0.0149      0.067     -0.223      0.824      -0.146       0.117
# meg                 -0.0473      0.085     -0.559      0.577      -0.214       0.119
# megmin               0.0269      0.061      0.443      0.659      -0.093       0.147
# megmax               0.0648      0.046      1.413      0.159      -0.026       0.155
# cmean                0.0843      0.123      0.688      0.492      -0.157       0.326
# cmin                -0.0204      0.027     -0.748      0.455      -0.074       0.033
Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.744
# Skew:                           1.142   Prob(JB):                     1.60e-16
# Kurtosis:                       3.836   Cond. No.                     1.33e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
xrp1 = rpv[cn]
ols_svp = result1.predict(xrp1)

# %%
plt.hist(ols_svp)
# Out:
# (array([ 15.,  85., 220., 254., 114.,  51.,  20.,  23.,   7.,   3.]),
#  array([-0.69149039, -0.45082508, -0.21015976,  0.03050555,  0.27117087,
#          0.51183618,  0.7525015 ,  0.99316681,  1.23383213,  1.47449744,
#          1.71516276]),
#  <BarContainer object of 10 artists>)

# %%
r1p = result1.pvalues

# %%
r1pdf = pd.DataFrame(r1p)
r1pdf = r1pdf.reset_index()

# %%
r1pdf.columns
# Out:
# Index(['index', 0], dtype='object')

# %%
print(r1pdf.nsmallest(15, 0))
# Out:
#              index         0
# 68         z_knr_2  0.000013
# 35         z_qnr_2  0.001610
# 89     r_surface_1  0.004711
# 24           droad  0.013364
# 81   trafficarea_3  0.026300
# 100     d_carcount  0.026400
# 85       r_width_4  0.027054
# 3            iemax  0.056219
# 25        droad_sl  0.068390
# 1               ie  0.089264
# 22           dcurb  0.093609
# 17        dstation  0.104993
# 97    bicyclecount  0.113508
# 34         z_qnr_1  0.122060
# 87       r_width_6  0.126989

# %%
a = r1pdf.nsmallest(15, 0)
ten1 = a['index'].to_list()

# %%
ten1
# Out:
# ['z_knr_2',
#  'z_qnr_2',
#  'r_surface_1',
#  'droad',
#  'trafficarea_3',
#  'd_carcount',
#  'r_width_4',
#  'iemax',
#  'droad_sl',
#  'ie',
#  'dcurb',
#  'dstation',
#  'bicyclecount',
#  'z_qnr_1',
#  'r_width_6']

# %%
y1 = acv['svp']
x1i = acv[ten1]
x1i = sm.add_constant(x1i)
model1i = sm.OLS(y1, x1i)
result1i = model1i.fit()
result1i.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    svp   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     3.330
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):           5.86e-05
# Time:                        03:07:33   Log-Likelihood:                -104.29
# No. Observations:                 295   AIC:                             238.6
# Df Residuals:                     280   BIC:                             293.9
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# z_knr_2           0.1087      0.149      0.730      0.466      -0.184       0.402
# z_qnr_2           0.6179      0.234      2.646      0.009       0.158       1.078
# r_surface_1       0.1130      0.026      4.267      0.000       0.061       0.165
# droad             0.2897      0.106      2.732      0.007       0.081       0.499
# trafficarea_3     0.1887      0.076      2.490      0.013       0.040       0.338
# d_carcount        0.0316      0.023      1.389      0.166      -0.013       0.076
# r_width_4         0.1052      0.053      1.978      0.049       0.001       0.210
# iemax            -0.1186      0.055     -2.152      0.032      -0.227      -0.010
# droad_sl         -0.2053      0.110     -1.870      0.063      -0.421       0.011
# ie                0.0937      0.055      1.700      0.090      -0.015       0.202
# dcurb            -0.0310      0.031     -0.992      0.322      -0.092       0.030
# dstation          0.0291      0.021      1.375      0.170      -0.013       0.071
# bicyclecount     -0.0426      0.021     -2.057      0.041      -0.083      -0.002
# z_qnr_1          -0.1554      0.089     -1.749      0.081      -0.330       0.019
# r_width_6         0.1195      0.087      1.371      0.172      -0.052       0.291
# ==============================================================================
# Omnibus:                       78.532   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.542
# Skew:                           1.550   Prob(JB):                     2.24e-30
# Kurtosis:                       4.226   Cond. No.                         19.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y2 = acv['lvp']
x = acv[cn]
x = sm.add_constant(x)
model2 = sm.OLS(y2, x)
result2 = model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    lvp   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.9854
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):              0.520
# Time:                        03:08:22   Log-Likelihood:                -137.90
# No. Observations:                 295   AIC:                             433.8
# Df Residuals:                     216   BIC:                             725.1
# Df Model:                          78
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# cp                   0.2824      0.275      1.028      0.305      -0.259       0.824
# ie                  -0.4945      0.272     -1.815      0.071      -1.031       0.042
# iemin                0.3661      0.168      2.179      0.030       0.035       0.697
# iemax                0.2324      0.138      1.690      0.092      -0.039       0.504
# mew                 -0.0214      0.149     -0.143      0.886      -0.315       0.272
# mewmin              -0.0242      0.099     -0.244      0.807      -0.220       0.171
# mewmax               0.0766      0.083      0.928      0.354      -0.086       0.239
# meg                  0.0588      0.105      0.562      0.575      -0.147       0.265
# megmin              -0.0089      0.075     -0.118      0.906      -0.157       0.139
# megmax              -0.0478      0.057     -0.843      0.400      -0.159       0.064
# cmean               -0.0639      0.152     -0.421      0.674      -0.363       0.235
# cmin                 0.0497      0.034      1.476      0.141      -0.017       0.116
# cmax                -0.0674      0.200     -0.337      0.736      -0.461       0.327
# dbusl               -0.0443      0.041     -1.086      0.279      -0.125       0.036
# dtraml              -0.0436      0.041     -1.054      0.293      -0.125       0.038
# dtrainl              0.0259      0.039      0.656      0.512      -0.052       0.104
# dplight              0.0328      0.033      0.987      0.325      -0.033       0.098
# dstation            -0.0488      0.035     -1.405      0.162      -0.117       0.020
# dparkcar             0.0332      0.040      0.838      0.403      -0.045       0.111
# dparktw              0.0223      0.039      0.577      0.564      -0.054       0.099
# dpedcro              0.0093      0.033      0.278      0.781      -0.057       0.075
# dstopsign           -0.0670      0.045     -1.496      0.136      -0.155       0.021
# dcurb                0.0806      0.058      1.398      0.163      -0.033       0.194
# dtrafficarea        -0.0594      0.047     -1.261      0.209      -0.152       0.033
# droad               -0.2858      0.176     -1.620      0.107      -0.633       0.062
# droad_sl             0.2881      0.181      1.596      0.112      -0.068       0.644
# dvfpath             -0.0210      0.047     -0.449      0.654      -0.113       0.071
# gvm_dwv             -0.2155      0.250     -0.861      0.390      -0.709       0.278
# gvm_msp              0.1918      0.213      0.901      0.368      -0.228       0.611
# gvm_asp             -0.0329      0.254     -0.129      0.897      -0.533       0.468
# r_width_value       -0.0622      0.050     -1.255      0.211      -0.160       0.036
# speedlimit_value    -0.0310      0.105     -0.296      0.767      -0.237       0.175
# curbtype_1           0.0534      0.074      0.721      0.472      -0.093       0.199
# curbtype_2           0.1861      0.081      2.292      0.023       0.026       0.346
# z_knr_10             0.0340      0.111      0.306      0.760      -0.185       0.253
# z_knr_11             0.0132      0.160      0.083      0.934      -0.302       0.329
# z_knr_12             0.0190      0.172      0.111      0.912      -0.320       0.358
# trafficarea_1        0.0444      0.073      0.611      0.542      -0.099       0.188
# trafficarea_2        0.2935      0.096      3.054      0.003       0.104       0.483
# trafficarea_3       -0.0985      0.117     -0.839      0.403      -0.330       0.133
# r_width_1            0.0441      0.083      0.532      0.595      -0.119       0.208
# r_width_2            0.1276      0.186      0.687      0.493      -0.238       0.493
# r_width_3            0.0393      0.087      0.453      0.651      -0.132       0.210
# r_width_4           -0.0785      0.076     -1.037      0.301      -0.228       0.071
# r_width_5            0.1425      0.070      2.047      0.042       0.005       0.280
# r_width_6           -0.0797      0.130     -0.613      0.541      -0.336       0.177
# r_width_7            0.0442      0.193      0.229      0.819      -0.336       0.425
# r_surface_1          0.2395      0.080      2.994      0.003       0.082       0.397
# r_surface_2               0          0        nan        nan           0           0
# speedlimit_1         0.1225      0.120      1.021      0.309      -0.114       0.359
# speedlimit_2         0.0154      0.153      0.101      0.920      -0.286       0.316
# speedlimit_3         0.9166      0.455      2.013      0.045       0.019       1.814
# speedlimit_4         0.1102      0.184      0.599      0.550      -0.253       0.473
# speedlimit_5        -0.6150      0.331     -1.858      0.064      -1.267       0.037
# speedlimit_6        -0.3103      0.200     -1.550      0.123      -0.705       0.084
# bicyclecount         0.0211      0.032      0.659      0.510      -0.042       0.084
# carcount             0.0273      0.036      0.763      0.446      -0.043       0.098
# d_bicyclecount       0.0454      0.047      0.957      0.340      -0.048       0.139
# d_carcount          -0.0272      0.041     -0.669      0.504      -0.107       0.053
# ==============================================================================
# Omnibus:                       24.353   Durbin-Watson:                   2.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.025
# Skew:                          -0.621   Prob(JB):                     1.00e-05
# Kurtosis:                       2.424   Cond. No.                     1.33e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
ols_lvp = result2.predict(xrp1)
plt.hist(ols_lvp)
# Out:
# (array([  4.,   2.,  19.,  38., 139., 238., 180., 110.,  51.,  11.]),
#  array([-1.02517647, -0.6820261 , -0.33887573,  0.00427463,  0.347425  ,
#          0.69057536,  1.03372573,  1.37687609,  1.72002646,  2.06317682,
#          2.40632719]),
#  <BarContainer object of 10 artists>)

# %%
r2p = result2.pvalues
r2pdf = pd.DataFrame(r2p)
r2pdf = r2pdf.reset_index()
a2 = r2pdf.nsmallest(15, 0)
print(a2)
ten2 = a2['index'].to_list()
# Out:
#             index         0
# 68        z_knr_2  0.000319
# 80  trafficarea_2  0.002546
# 89    r_surface_1  0.003079
# 33     curbtype_2  0.022875
# 2           iemin  0.030433
# 86      r_width_5  0.041903
# 75        z_knr_9  0.042712
# 70        z_knr_4  0.045252
# 93   speedlimit_3  0.045320
# 35        z_qnr_2  0.063167
# 95   speedlimit_5  0.064470
# 1              ie  0.070861
# 3           iemax  0.092488
# 53       z_qnr_20  0.105906
# 24          droad  0.106624

# %%
y2 = acv['lvp']
x2i = acv[ten2]
x2i = sm.add_constant(x2i)
model2i = sm.OLS(y2, x2i)
result2i = model2i.fit()
result2i.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    lvp   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     1.920
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):             0.0243
# Time:                        03:09:53   Log-Likelihood:                -169.28
# No. Observations:                 295   AIC:                             368.6
# Df Residuals:                     280   BIC:                             423.9
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# z_knr_2          -0.3546      0.185     -1.917      0.056      -0.719       0.010
# trafficarea_2     0.0482      0.091      0.531      0.596      -0.130       0.227
# r_surface_1       0.6626      0.047     13.973      0.000       0.569       0.756
# curbtype_2        0.1533      0.085      1.801      0.073      -0.014       0.321
# iemin             0.2156      0.144      1.494      0.136      -0.068       0.500
# r_width_5         0.0281      0.057      0.493      0.623      -0.084       0.140
# z_knr_9           0.1167      0.071      1.641      0.102      -0.023       0.257
# z_knr_4           0.0931      0.069      1.341      0.181      -0.044       0.230
# speedlimit_3      0.3113      0.455      0.684      0.495      -0.585       1.208
# z_qnr_2          -0.2166      0.298     -0.728      0.467      -0.802       0.369
# speedlimit_5     -0.8102      0.450     -1.799      0.073      -1.697       0.076
# ie               -0.2888      0.234     -1.233      0.219      -0.750       0.172
# iemax             0.1508      0.116      1.296      0.196      -0.078       0.380
# z_qnr_20         -0.1738      0.130     -1.339      0.182      -0.429       0.082
# droad             0.0156      0.028      0.560      0.576      -0.039       0.071
# ==============================================================================
# Omnibus:                       52.942   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.121
# Skew:                          -0.932   Prob(JB):                     1.31e-11
# Kurtosis:                       2.222   Cond. No.                         29.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y3 = acv['pdp']
x = acv[cn]
x = sm.add_constant(x)
model3 = sm.OLS(y3, x)
result3 = model3.fit()
result3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pdp   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     1.165
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):              0.196
# Time:                        03:09:54   Log-Likelihood:                -162.30
# No. Observations:                 295   AIC:                             482.6
# Df Residuals:                     216   BIC:                             773.9
# Df Model:                          78
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# cp                   0.0951      0.298      0.318      0.750      -0.493       0.683
# ie                  -0.2680      0.296     -0.906      0.366      -0.851       0.315
# iemin                0.0829      0.183      0.454      0.650      -0.277       0.443
# iemax                0.1950      0.149      1.305      0.193      -0.099       0.489
# mew                  0.0245      0.162      0.151      0.880      -0.295       0.344
# mewmin               0.0053      0.108      0.049      0.961      -0.207       0.218
# mewmax               0.0195      0.090      0.217      0.828      -0.157       0.196
# meg                  0.0455      0.114      0.400      0.689      -0.178       0.269
# megmin              -0.0230      0.082     -0.282      0.778      -0.184       0.138
# megmax              -0.0862      0.062     -1.400      0.163      -0.208       0.035
# cmean               -0.1673      0.165     -1.016      0.311      -0.492       0.157
# cmin                -0.0421      0.037     -1.150      0.251      -0.114       0.030
# cmax                 0.1288      0.217      0.593      0.554      -0.299       0.557
# dbusl               -0.0398      0.044     -0.898      0.370      -0.127       0.048
# dtraml              -0.0203      0.045     -0.451      0.653      -0.109       0.068
# dtrainl             -0.0122      0.043     -0.285      0.776      -0.097       0.072
+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
ols_pdp = result3.predict(xrp1)
plt.hist(ols_pdp)
# Out:
# (array([  3.,   8.,  25.,  91., 147., 211., 157., 102.,  32.,  16.]),
#  array([-0.70582296, -0.46828583, -0.2307487 ,  0.00678843,  0.24432555,
#          0.48186268,  0.71939981,  0.95693694,  1.19447407,  1.4320112 ,
#          1.66954833]),
#  <BarContainer object of 10 artists>)

# %%
r3p = result3.pvalues
r3pdf = pd.DataFrame(r3p)
r3pdf = r3pdf.reset_index()
a3 = r2pdf.nsmallest(15, 0)
print(a3)
ten3 = a3['index'].to_list()
# Out:
#             index         0
# 68        z_knr_2  0.000319
# 80  trafficarea_2  0.002546
# 89    r_surface_1  0.003079
# 33     curbtype_2  0.022875
# 2           iemin  0.030433
# 86      r_width_5  0.041903
# 75        z_knr_9  0.042712
# 70        z_knr_4  0.045252
# 93   speedlimit_3  0.045320
# 35        z_qnr_2  0.063167
# 95   speedlimit_5  0.064470
# 1              ie  0.070861
# 3           iemax  0.092488
# 53       z_qnr_20  0.105906
# 24          droad  0.106624

# %%
y3 = acv['pdp']
x3i = acv[ten3]
x3i = sm.add_constant(x3i)
model3i = sm.OLS(y3, x3i)
result3i = model3i.fit()
result3i.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pdp   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     2.171
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):            0.00903
# Time:                        03:09:55   Log-Likelihood:                -198.89
# No. Observations:                 295   AIC:                             427.8
# Df Residuals:                     280   BIC:                             483.1
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# z_knr_2           0.4310      0.205      2.107      0.036       0.028       0.834
# trafficarea_2    -0.1177      0.100     -1.173      0.242      -0.315       0.080
# r_surface_1       0.5131      0.052      9.787      0.000       0.410       0.616
# curbtype_2       -0.0268      0.094     -0.285      0.776      -0.212       0.158
# iemin             0.1214      0.159      0.761      0.447      -0.193       0.435
# r_width_5         0.0240      0.063      0.380      0.704      -0.100       0.148
# z_knr_9          -0.1065      0.079     -1.355      0.177      -0.261       0.048
# z_knr_4          -0.0067      0.077     -0.088      0.930      -0.158       0.144
# speedlimit_3      0.4217      0.503      0.838      0.403      -0.569       1.412
# z_qnr_2          -0.5189      0.329     -1.577      0.116      -1.166       0.129
# speedlimit_5     -0.4019      0.498     -0.807      0.420      -1.382       0.578
# ie               -0.3073      0.259     -1.187      0.236      -0.817       0.202
# iemax             0.1984      0.129      1.542      0.124      -0.055       0.452
# z_qnr_20          0.2567      0.144      1.788      0.075      -0.026       0.539
# droad            -0.1083      0.031     -3.511      0.001      -0.169      -0.048
# ==============================================================================
# Omnibus:                     1913.011   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.227
# Skew:                           0.031   Prob(JB):                     2.24e-08
# Kurtosis:                       1.308   Cond. No.                         29.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y4 = acv['LV']
x = acv[cn]
x = sm.add_constant(x)
model4 = sm.OLS(y4, x)
result4 = model4.fit()
result4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     LV   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.9279
# Date:                Fri, 26 Apr 2024   Prob (F-statistic
# r_width_6           -0.0864      0.157     -0.552      0.582      -0.395       0.222
# r_width_7            0.0674      0.233      0.290      0.772      -0.391       0.526
# r_surface_1          0.2882      0.096      2.991      0.003       0.098       0.478
# r_surface_2               0          0        nan        nan           0           0
# speedlimit_1         0.1306      0.145      0.903      0.368      -0.155       0.416
# speedlimit_2        -0.0092      0.184     -0.050      0.960      -0.372       0.353
# speedlimit_3         1.0690      0.548      1.949      0.053      -0.012       2.150
# speedlimit_4         0.1001      0.222      0.452      0.652      -0.337       0.537
# speedlimit_5        -0.7008      0.399     -1.758      0.080      -1.487       0.085
# speedlimit_6        -0.3014      0.241     -1.250      0.213      -0.777       0.174
# bicyclecount         0.0042      0.039      0.109      0.913      -0.072       0.080
# carcount             0.0584      0.043      1.356      0.177      -0.027       0.143
# d_bicyclecount       0.0685      0.057      1.199      0.232      -0.044       0.181
# d_carcount          -0.0323      0.049     -0.660      0.510      -0.129       0.064
# ==============================================================================
# Omnibus:                        0.549   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.760   Jarque-Bera (JB):                0.331
# Skew:                          -0.048   Prob(JB):                        0.847
# Kurtosis:                       3.133   Cond. No.                     1.33e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
ols_lv = result4.predict(xrp1)
plt.hist(ols_lv)
# Out:
# (array([  3.,  18.,  36., 155., 250., 134., 121.,  59.,  15.,   1.]),
#  array([-0.92983078, -0.51599596, -0.10216115,  0.31167367,  0.72550849,
#          1.13934331,  1.55317813,  1.96701294,  2.38084776,  2.79468258,
#          3.2085174 ]),
#  <BarContainer object of 10 artists>)

# %%
y6 = acv['SV']
x = acv[cn]
x = sm.add_constant(x)
model6 = sm.OLS(y6, x)
result6 = model6.fit()
result6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     SV   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     1.162
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):              0.201
# Time:                        03:10:05   Log-Likelihood:                -75.343
# No. Observations:                 295   AIC:                             308.7
# Df Residuals:                     216   BIC:                             600.0
# Df Model:                          78
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# cp                  -0.1168      0.222     -0.525      0.600      -0.555       0.321
# ie                   0.3761      0.220      1.707      0.089      -0.058       0.810
# iemin               -0.1795      0.136     -1.321      0.188      -0.447       0.088
# iemax               -0.2136      0.111     -1.920      0.056      -0.433       0.006
# mew                 -0.0911      0.121     -0.755      0.451      -0.329       0.147
# mewmin               0.0638      0.080      0.794      0.428      -0.095       0.222
# mewmax              -0.0149      0.067     -0.223      0.824      -0.146       0.117
# meg                 -0.0473      0.085     -0.559      0.577      -0.214       0.119
# megmin               0.0269      0.061      0.443      0.659      -0.093       0.147
# megmax               0.0648      0.046      1.413      0.159      -0.026       0.155
# cmean                0.0843      0.123      0.688      0.492      -0.157       0.326
# cmin                -0.0204      0.027     -0.748      0.455      -0.074       0.033
# cmax                -0.0316      0.162     -0.195      0.845      -0.350       0.287
# dbusl                0.0046      0.033      0.140      0.889      -0.060       0.070
# dtraml              -0.0178      0.033     -0.531      0.596      -0.084       0.048
# dtrainl             -0.0489      0.032     -1.530      0.127      -0.112       0.014
# dplight             -0.0278      0.027     -1.034      0.302      -0.081       0.025
# dstation             0.0458      0.028      1.628      0.105      -0.010       0.101
-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
ols_sv = result6.predict(xrp1)
plt.hist(ols_sv)
# Out:
# (array([ 15.,  85., 220., 254., 114.,  51.,  20.,  23.,   7.,   3.]),
#  array([-0.69149039, -0.45082508, -0.21015976,  0.03050555,  0.27117087,
#          0.51183618,  0.7525015 ,  0.99316681,  1.23383213,  1.47449744,
#          1.71516276]),
#  <BarContainer object of 10 artists>)

# %%
y5 = acv['pd']
x = acv[cn]
x = sm.add_constant(x)
model5 = sm.OLS(y5, x)
result5 = model5.fit()
result5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     pd   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                    0.9078
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):              0.686
# Time:                        04:15:09   Log-Likelihood:                -2777.9
# No. Observations:                 295   AIC:                             5714.
# Df Residuals:                     216   BIC:                             6005.
# Df Model:                          78
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# cp               -2508.4034   2116.444     -1.185      0.237   -6679.931    1663.124
# ie               -4439.9401   2098.001     -2.116      0.035   -8575.117    -304.764
# iemin             1456.1297   1294.242      1.125      0.262   -1094.830    4007.090
# iemax             2747.5307   1059.307      2.594      0.010     659.629    4835.432
# mew                337.0936   1148.263      0.294      0.769   -1926.141    2600.329
# mewmin            -363.4661    764.683     -0.475      0.635   -1870.663    1143.730
# mewmax            -155.8114    635.418     -0.245      0.807   -1408.225    1096.602
# meg               -586.2897    805.499     -0.728      0.467   -2173.934    1001.355
# megmin             161.4977    578.764      0.279      0.780    -979.251    1302.246
# megmax             448.9351    436.531      1.028      0.305    -411.471    1309.341
# cmean              390.0175   1167.226      0.334      0.739   -1910.594    2690.629
# cmin              -255.2527    259.543     -0.983      0.326    -766.815     256.309
# cmax               831.7132   1539.546      0.540      0.590   -2202.744    3866.171
# dbusl             -311.3109    314.255     -0.991      0.323    -930.709     308.087
# dtraml              91.0756    318.713      0.286      0.775    -537.110     719.261
# dtrainl            191.6776    304.221      0.630      0.529    -407.944     791.299
# dplight            258.6242    256.237      1.009      0.314    -246.421     763.670
# dstation           339.4634    267.714      1.268      0.206    -188.204     867.131
# dparkcar          -147.4770    305.131     -0.483      0.629    -748.893     453.939
# dparktw           -253.5965    297.947     -0.851      0.396    -840.852     333.659
# dpedcro           -359.1372    257.691     -1.394      0.165    -867.048     148.774
# dstopsign          301.0168    345.105      0.872      0.384    -379.188     981.222
# dcurb              -87.2925    443.676     -0.197      0.844    -961.781     787.196
# dtrafficarea        65.7031    362.911      0.181      0.857    -649.597     781.003
# droad             -244.4181   1358.382     -0.180      0.857   -2921.799    2432.963
# droad_sl          -246.9739   1390.712     -0.178      0.859   -2988.078    2494.131
# dvfpath            279.7366    360.906      0.775      0.439    -431.612     991.085
# gvm_dwv          -1466.7128   1926.623     -0.761      0.447   -5264.101    2330.675
# gvm_msp             24.1308   1638.473      0.015      0.988   -3205.311    3253.573
# gvm_asp           1734.9464   1956.050      0.887      0.376   -2120.443    5590.336
# r_width_value      -16.6112    381.790     -0.044      0.965    -769.123     735.901
# speedlimit_value   202.8210    805.599      0.252      0.801   -1385.021    1790.663
# curbtype_1         443.2157    570.574      0.777      0.438    -681.390    1567.821
# z_knr_6           -290.1853    668.572     -0.434      0.665   -1607.946    1027.575
# z_knr_7           -312.2075    721.921     -0.432      0.666   -1735.120    1110.705
# z_knr_8           -817.9306   1252.314     -0.653      0.514   -3286.252    1650.390
# z_knr_9           1998.7885    815.912      2.450      0.015     390.620    3606.956
# z_knr_10          -629.4617    857.256     -0.734      0.464   -2319.119    1060.196
# z_knr_11           429.1252   1233.777      0.348      0.728   -2002.659    2860.909
# z_knr_12           219.5559   1323.329      0.166      0.868   -2388.736    2827.848
# trafficarea_1      546.4839    560.054      0.976      0.330    -557.387    1650.354
# trafficarea_2     1962.3786    740.283      2.651      0.009     503.275    3421.482
# trafficarea_3    -2021.9421    904.271     -2.236      0.026   -3804.266    -239.618
# r_width_1         -333.6057    638.761     -0.522      0.602   -1592.609     925.397
# r_width_2         -991.4692   1429.579     -0.694      0.489   -3809.180    1826.241
# r_width_3           83.0003    668.755      0.124      0.901   -1235.121    1401.122
# r_width_4          -56.9819    583.010     -0.098      0.922   -1206.100    1092.136
# r_width_5          558.4717    536.138      1.042      0.299    -498.261    1615.204
# r_width_6         -100.6279   1001.807     -0.100      0.920   -2075.196    1873.941
# r_width_7         1328.1331   1486.743      0.893      0.373   -1602.248    4258.515
# r_surface_1        486.9205    616.113      0.790      0.430    -727.443    1701.284
# r_surface_2               0          0        nan        nan           0           0
# speedlimit_1       811.7870    924.737      0.878      0.381   -1010.877    2634.451
# speedlimit_2       381.6696   1175.786      0.325      0.746   -1935.813    2699.152
# speedlimit_3      1063.6204   3506.473      0.303      0.762   -5847.664    7974.905
# speedlimit_4       435.4244   1417.350      0.307      0.759   -2358.183    3229.032
# speedlimit_5      -736.6005   2548.615     -0.289      0.773   -5759.940    4286.739
# speedlimit_6     -1468.9805   1542.043     -0.953      0.342   -4508.359    1570.398
# bicyclecount       267.7401    246.588      1.086      0.279    -218.286     753.767
# carcount           251.9625    275.570      0.914      0.362    -291.188     795.113
# d_bicyclecount     -80.9901    365.322     -0.222      0.825    -801.043     639.063
# d_carcount         236.7370    312.884      0.757      0.450    -379.960     853.434
# ==============================================================================
# Omnibus:                      464.581   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           134720.140
# Skew:                           7.939   Prob(JB):                         0.00
# Kurtosis:                     106.480   Cond. No.                     1.33e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
ols_pd = result5.predict(xrp1)
plt.hist(ols_pd)
# Out:
# (array([  1.,   8.,  38., 145., 206., 205., 116.,  53.,  15.,   5.]),
#  array([-6766.49525067, -5319.81409893, -3873.13294719, -2426.45179545,
#          -979.7706437 ,   466.91050804,  1913.59165978,  3360.27281152,
#          4806.95396327,  6253.63511501,  7700.31626675]),
#  <BarContainer object of 10 artists>)

# %%
y11 = acv['inp']
x = acv[cn]
x = sm.add_constant(x)
model11 = sm.OLS(y11, x)
result11 = model11.fit()
result11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    inp   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     1.158
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):              0.205
# Time:                        04:15:36   Log-Likelihood:                -50.831
# No. Observations:                 295   AIC:                             259.7
# Df Residuals:                     216   BIC:                             550.9
# Df Model:                          78
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# r_surface_1          0.3984      0.060      6.691      0.000       0.281       0.516
# r_surface_2               0          0        nan        nan           0           0
# speedlimit_1         0.1436      0.089      1.606      0.110      -0.033       0.320
# speedlimit_2         0.2074      0.114      1.825      0.069      -0.017       0.431
# speedlimit_3         0.4491      0.339      1.325      0.187      -0.219       1.117
# speedlimit_4        -0.0272      0.137     -0.198      0.843      -0.297       0.243
# speedlimit_5        -0.1161      0.246     -0.471      0.638      -0.602       0.369
# speedlimit_6        -0.2583      0.149     -1.733      0.084      -0.552       0.035
# bicyclecount        -0.0210      0.024     -0.880      0.380      -0.068       0.026
# carcount            -0.0093      0.027     -0.348      0.728      -0.062       0.043
# d_bicyclecount      -0.0042      0.035     -0.118      0.906      -0.074       0.065
# d_carcount           0.0297      0.030      0.981      0.328      -0.030       0.089
# ==============================================================================
# Omnibus:                       71.237   Durbin-Watson:                   2.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              123.411
# Skew:                          -1.348   Prob(JB):                     1.59e-27
# Kurtosis:                       4.664   Cond. No.                     1.33e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.48e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
ols_inp = result11.predict(xrp1)
plt.hist(ols_inp)
# Out:
# (array([ 10.,  22.,  67., 138., 206., 151.,  98.,  62.,  30.,   8.]),
#  array([0.21972014, 0.39025938, 0.56079863, 0.73133787, 0.90187711,
#         1.07241636, 1.2429556 , 1.41349485, 1.58403409, 1.75457334,
#         1.92511258]),
#  <BarContainer object of 10 artists>)

# %%
# Presence or not
y7 = acv['svp']
y8 = acv['lvp']
y9 = acv['pdp']
y10 = acv['inp']
x = acv[cn]

# %%
# SVP 7
X_train7, X_test7, y_train7, y_test7 = train_test_split(x, y7, 
                                                        test_size = 0.3, random_state = 7)
rfc7 = RandomForestClassifier(n_estimators=6, max_depth=16, 
                              random_state = 7) # 6 because of following codes to find the best number of trees
rfc7.fit(X_train7, y_train7)
y_pred_rfc7 = rfc7.predict(X_test7)
print("Train data accuracy:",accuracy_score(y_true = y_train7, y_pred = rfc7.predict(X_train7)))
print("Test data accuracy:",accuracy_score(y_true = y_test7, y_pred = y_pred_rfc7))
confusion_matrix_rfc7 = metrics.confusion_matrix(y_test7, y_pred_rfc7)
cm_display_rfc7 = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_rfc7)
cm_display_rfc7.plot(cmap = 'PuBu')
plt.box(False)
acc_rfc7 = metrics.accuracy_score(y_test7, y_pred_rfc7)
print('accuracy', acc_rfc7)
pre_rfc7 = metrics.precision_score(y_test7, y_pred_rfc7, average = None)
print('precision', pre_rfc7)
senrec_rfc7 = metrics.recall_score(y_test7, y_pred_rfc7, average = None)
print('sensitivity recall', senrec_rfc7)
f1_rfc7 = metrics.f1_score(y_test7, y_pred_rfc7, average = None)
print('f1 score', f1_rfc7)
mcc_rfc7 = metrics.matthews_corrcoef(y_test7, y_pred_rfc7)
print('mcc score', mcc_rfc7)
ka_rfc7 = metrics.cohen_kappa_score(y_test7, y_pred_rfc7)
print('kappa', ka_rfc7)
# Out:
# Train data accuracy: 0.9466019417475728
# Test data accuracy: 0.8764044943820225
# accuracy 0.8764044943820225
# precision [0.88505747 0.5       ]
# sensitivity recall [0.98717949 0.09090909]
# f1 score [0.93333333 0.15384615]
# mcc score 0.17340297117817213
# kappa 0.12039532794249774

# %%
joblib.dump(rfc7, "pm_svp.joblib")
# Out:
# ['pm_svp.joblib']

# %%
rf = RandomForestClassifier(n_estimators=20, max_depth=16, n_jobs=-1)
rf.fit(X_train7, y_train7)
predictions = []
for tree in rf.estimators_:
    predictions.append(tree.predict_proba(X_test7)[None, :])
predictions = np.vstack(predictions)
cum_mean = np.cumsum(predictions, axis=0)/np.arange(1, predictions.shape[0] + 1)[:, None, None]
scores = []
for pred in cum_mean:
    scores.append(accuracy_score(y_test7, np.argmax(pred, axis=1)))
plt.figure(figsize=(10, 6))
plt.plot(scores, linewidth=3)
plt.xlabel('num_trees')
plt.ylabel('accuracy')
# best n_estimator 6
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# Text(0, 0.5, 'accuracy')

# %%
feature_name = list(x.columns.values.tolist())
importances = rfc7.feature_importances_
df_rfc7 = pd.DataFrame({'features':feature_name, 'importances':importances})
df_rfc7.sort_values(by = ['importances'], ascending = False, inplace = True)
df_rfc7t = df_rfc7.nlargest(15, 'importances')
plt.figure(figsize = [12,8])
sn.barplot(x = df_rfc7t['importances'], y = df_rfc7t['features'],palette = "PuBu_r")
plt.xlabel('importance')
plt.ylabel('feature')
plt.box(False)
# plt.savefig('svp_rf_importance.png')

# %%
# LVP 8
X_train8, X_test8, y_train8, y_test8 = train_test_split(x, y8, 
                                                        test_size = 0.4, 
                                                        random_state = 8)
rfc8 = RandomForestClassifier(n_estimators = 12, max_depth=8,random_state = 8)
rfc8.fit(X_train8, y_train8)
y_pred_rfc8 = rfc8.predict(X_test8)
print("Train data accuracy:",accuracy_score(y_true = y_train8, y_pred = rfc8.predict(X_train8)))
print("Test data accuracy:",accuracy_score(y_true = y_test8, y_pred = y_pred_rfc8))
confusion_matrix_rfc8 = metrics.confusion_matrix(y_test8, y_pred_rfc8)
cm_display_rfc8 = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_rfc8)
cm_display_rfc8.plot(cmap = 'PuBu')
# cm_display_rfc7.plot(cmap = 'PuBu')
acc_rfc8 = metrics.accuracy_score(y_test8, y_pred_rfc8)
print('accuracy', acc_rfc8)
pre_rfc8 = metrics.precision_score(y_test8, y_pred_rfc8, average = None)
print('precision', pre_rfc8)
senrec_rfc8 = metrics.recall_score(y_test8, y_pred_rfc8, average = None)
print('sensitivity recall', senrec_rfc8)
f1_rfc8 = metrics.f1_score(y_test8, y_pred_rfc8, average = None)
print('f1 score', f1_rfc8)
mcc_rfc8 = metrics.matthews_corrcoef(y_test8, y_pred_rfc8)
print('mcc score', mcc_rfc8)
ka_rfc8 = metrics.cohen_kappa_score(y_test8, y_pred_rfc8)
print('kappa', ka_rfc8)
# Out:
# Train data accuracy: 0.9887005649717514
# Test data accuracy: 0.6440677966101694
# accuracy 0.6440677966101694
# precision [0.21428571 0.70192308]
# sensitivity recall [0.08823529 0.86904762]
# f1 score [0.125      0.77659574]
# mcc score -0.05982738789151156
# kappa -0.051782682512733436

# %%
joblib.dump(rfc8, "pm_lvp.joblib")
# Out:
# ['pm_lvp.joblib']

# %%
# rf = RandomForestClassifier(n_estimators=30, max_depth=6, n_jobs=-1)
# rf.fit(X_train8, y_train8)
# predictions = []
# for tree in rf.estimators_:
#     predictions.append(tree.predict_proba(X_test8)[None, :])
# predictions = np.vstack(predictions)
# cum_mean = np.cumsum(predictions, axis=0)/np.arange(1, predictions.shape[0] + 1)[:, None, None]
# scores = []
# for pred in cum_mean:
#     scores.append(accuracy_score(y_test8, np.argmax(pred, axis=1)))
# plt.figure(figsize=(10, 6))
# plt.plot(scores, linewidth=3)
# plt.xlabel('num_trees')
# plt.ylabel('accuracy')
# # # best n_estimator 12
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# Text(0, 0.5, 'accuracy')

# %%
feature_name = list(x.columns.values.tolist())
importances = rfc8.feature_importances_
df_rfc8 = pd.DataFrame({'features':feature_name, 'importances':importances})
df_rfc8.sort_values(by = ['importances'], ascending = False, inplace = True)
df_rfc8t = df_rfc8.nlargest(15, 'importances')
plt.figure(figsize = [12,8])
sn.barplot(x = df_rfc8t['importances'], y = df_rfc8t['features'],palette = "PuBu_r")
plt.xlabel('importance')
plt.ylabel('feature')
# plt.savefig('lvp_rf_importance.png')
# Out:
# Text(0, 0.5, 'feature')

# %%
# pdp 9
X_train9, X_test9, y_train9, y_test9 = train_test_split(x, y9, 
                                                        test_size = 0.3, 
                                                        random_state = 9)
rfc9 = RandomForestClassifier(n_estimators = 15, max_depth = 6, random_state = 9) # n_estimators setting from following codes
rfc9.fit(X_train9, y_train9)
y_pred_rfc9 = rfc9.predict(X_test9)
print("Train data accuracy:",accuracy_score(y_true = y_train9, y_pred = rfc9.predict(X_train9)))
print("Test data accuracy:",accuracy_score(y_true = y_test9, y_pred = y_pred_rfc9))
confusion_matrix_rfc9 = metrics.confusion_matrix(y_test9, y_pred_rfc9)
cm_display_rfc9 = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_rfc9)
cm_display_rfc9.plot(cmap = 'PuBu')
acc_rfc9 = metrics.accuracy_score(y_test9, y_pred_rfc9)
print('accuracy', acc_rfc9)
pre_rfc9 = metrics.precision_score(y_test9, y_pred_rfc9, average = None)
print('precision', pre_rfc9)
senrec_rfc9 = metrics.recall_score(y_test9, y_pred_rfc9, average = None)
print('sensitivity recall', senrec_rfc9)
f1_rfc9 = metrics.f1_score(y_test9, y_pred_rfc9, average = None)
print('f1 score', f1_rfc9)
mcc_rfc9 = metrics.matthews_corrcoef(y_test9, y_pred_rfc9)
print('mcc score', mcc_rfc9)
ka_rfc9 = metrics.cohen_kappa_score(y_test9, y_pred_rfc9)
print('kappa', ka_rfc9)
# Out:
# Train data accuracy: 0.9660194174757282
# Test data accuracy: 0.651685393258427
# accuracy 0.651685393258427
# precision [0.6        0.70454545]
# sensitivity recall [0.675      0.63265306]
# f1 score [0.63529412 0.66666667]
# mcc score 0.30609531419626923
# kappa 0.30416141235813365

# %%
# joblib.dump(rfc9, "pm_pdp.joblib")
# Out:
# ['pm_pdp.joblib']

# %%
# rf = RandomForestClassifier(n_estimators=20, max_depth=5, n_jobs=-1)
# rf.fit(X_train9, y_train9)
# predictions = []
# for tree in rf.estimators_:
#     predictions.append(tree.predict_proba(X_test9)[None, :])
# predictions = np.vstack(predictions)
# cum_mean = np.cumsum(predictions, axis=0)/np.arange(1, predictions.shape[0] + 1)[:, None, None]
# scores = []
# for pred in cum_mean:
#     scores.append(accuracy_score(y_test9, np.argmax(pred, axis=1)))
# plt.figure(figsize=(10, 6))
# plt.plot(scores, linewidth=3)
# plt.xlabel('num_trees')
# plt.ylabel('accuracy')
# # best n_estimator 15
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# Text(0, 0.5, 'accuracy')

# %%
feature_name = list(x.columns.values.tolist())
importances = rfc9.feature_importances_
df_rfc9 = pd.DataFrame({'features':feature_name, 'importances':importances})
df_rfc9.sort_values(by = ['importances'], ascending = False, inplace = True)
df_rfc9t = df_rfc9.nlargest(15, 'importances')
plt.figure(figsize = [12,8])
sn.barplot(x = df_rfc9t['importances'], y = df_rfc9t['features'],palette = "PuBu_r")
plt.xlabel('importance')
plt.ylabel('feature')
# plt.savefig('pd_rf_importance.png')
# Out:
# Text(0, 0.5, 'feature')

# %%
# inp 10
X_train10, X_test10, y_train10, y_test10 = train_test_split(x, y10, 
                                                        test_size = 0.4, 
                                                        random_state = 10)
rfc10 = RandomForestClassifier(n_estimators = 12, max_depth = 8, random_state = 10) # n_estimators setting from following codes
rfc10.fit(X_train10, y_train10)
y_pred_rfc10 = rfc10.predict(X_test10)
print("Train data accuracy:",accuracy_score(y_true = y_train10, y_pred = rfc10.predict(X_train10)))
print("Test data accuracy:",accuracy_score(y_true = y_test10, y_pred = y_pred_rfc10))
confusion_matrix_rfc10 = metrics.confusion_matrix(y_test10, y_pred_rfc10)
cm_display_rfc10 = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_rfc10)
cm_display_rfc10.plot(cmap = 'PuBu')
acc_rfc10 = metrics.accuracy_score(y_test10, y_pred_rfc10)
print('accuracy', acc_rfc10)
pre_rfc10 = metrics.precision_score(y_test10, y_pred_rfc10, average = None)
print('precision', pre_rfc10)
senrec_rfc10 = metrics.recall_score(y_test10, y_pred_rfc10, average = None)
print('sensitivity recall', senrec_rfc10)
f1_rfc10 = metrics.f1_score(y_test10, y_pred_rfc10, average = None)
print('f1 score', f1_rfc10)
mcc_rfc10 = metrics.matthews_corrcoef(y_test10, y_pred_rfc10)
print('mcc score', mcc_rfc10)
ka_rfc10 = metrics.cohen_kappa_score(y_test10, y_pred_rfc10)
print('kappa', ka_rfc10)
# Out:
# Train data accuracy: 0.9943502824858758
# Test data accuracy: 0.8135593220338984
# accuracy 0.8135593220338984
# precision [0.33333333 0.82608696]
# sensitivity recall [0.04761905 0.97938144]
# f1 score [0.08333333 0.89622642]
# mcc score 0.06560812517043504
# kappa 0.04065040650406493

# %%
joblib.dump(rfc10, "pm_inp.joblib")
# Out:
# ['pm_inp.joblib']

# %%
# rf = RandomForestClassifier(n_estimators=20, max_depth=5, n_jobs=-1)
# rf.fit(X_train10, y_train10)
# predictions = []
# for tree in rf.estimators_:
#     predictions.append(tree.predict_proba(X_test10)[None, :])
# predictions = np.vstack(predictions)
# cum_mean = np.cumsum(predictions, axis=0)/np.arange(1, predictions.shape[0] + 1)[:, None, None]
# scores = []
# for pred in cum_mean:
#     scores.append(accuracy_score(y_test10, np.argmax(pred, axis=1)))
# plt.figure(figsize=(10, 6))
# plt.plot(scores, linewidth=3)
# plt.xlabel('num_trees')
# plt.ylabel('accuracy')
# # best n_estimator 12
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# Text(0, 0.5, 'accuracy')

# %%
feature_name = list(x.columns.values.tolist())
importances = rfc10.feature_importances_
df_rfc10 = pd.DataFrame({'features':feature_name, 'importances':importances})
df_rfc10.sort_values(by = ['importances'], ascending = False, inplace = True)
df_rfc10t = df_rfc10.nlargest(15, 'importances')
plt.figure(figsize = [12,8])
sn.barplot(x = df_rfc10t['importances'], y = df_rfc10t['features'],palette = "PuBu_r")
plt.xlabel('importance')
plt.ylabel('feature')
# plt.savefig('pd_rf_importance.png')
# Out:
# Text(0, 0.5, 'feature')

# %%
# rfc7 svp
# rfc8 lvp
# rfc9 pdp
# rfc10 inp

# %%
xrpv = rpv[cn]

# %%
rp_pred_svp = rfc7.predict(xrpv)
rp_pred_lvp = rfc8.predict(xrpv)
rp_pred_pdp = rfc9.predict(xrpv)
rp_pred_inp = rfc10.predict(xrpv)

# %%
xrpvr = xrpv.copy(deep =True)

# %%
xrpvr['svp'] = rp_pred_svp
xrpvr['lvp'] = rp_pred_lvp
xrpvr['pdp'] = rp_pred_pdp
xrpvr['inp'] = rp_pred_inp

# %%
df_rpsvp = pd.merge(rpv, xrpvr, on = cn)

# %%
df_rpsvp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Columns: 115 entries, id to inp
# dtypes: float64(35), int64(78), object(2)
# memory usage: 711.7+ KB

# %%
dfvpcopy = df_rpsvp.copy(deep =True)
pred_rp_class = dfvpcopy.drop(cn, axis = 1)

# %%
pred_rp_class.columns
# Out:
# Index(['id', 'curbtype', 'z_qnr', 'z_knr', 'trafficarea', 'r_width',
#        'r_surface', 'speedlimit', 'z_qnr_34', 'speedlimit_7', 'svp', 'lvp',
#        'pdp', 'inp'],
#       dtype='object')

# %%
pred_rp_class = pred_rp_class.drop(['curbtype', 'z_qnr', 'z_knr', 'trafficarea', 'r_width',
                                    'r_surface', 'speedlimit', 'z_qnr_34', 'speedlimit_7'], axis = 1)

# %%
pred_rp_class.to_csv('/home/yelhe/script/mt/model/rp_result.csv', index = False)

# %%
pred_rp_class.groupby(['inp']).size()
# Out:
# inp
# 1    792
# dtype: int64

# %%
rf_ols = pred_rp_class.copy(deep = True)
rf_ols['ols_svp'] = ols_svp
rf_ols['ols_lvp'] = ols_lvp
rf_ols['ols_pdp'] = ols_pdp
rf_ols['ols_inp'] = ols_inp
rf_ols['ols_sv'] = ols_sv
rf_ols['ols_lv'] = ols_lv
rf_ols['ols_pd'] = ols_pd

# %%
rf_ols.to_csv('/home/yelhe/script/mt/model/rp_result_rf_ols.csv', index = False)

# %%
rf_ols['']
# Out:
#       id  svp  lvp  pdp  inp   ols_svp   ols_lvp   ols_pdp   ols_inp  \
# 0      2    0    1    1    1  1.102436  0.756437  0.670158  1.540897
# 1      3    0    1    1    1  0.870328  0.450106  1.265953  1.102394
# 2      4    0    1    1    1  0.155012  0.508393  0.832326  0.693585
# 3      5    0    1    1    1  0.183000  0.763251  0.953650  0.930818
# 4      6    0    1    1    1  0.027868  0.912445  0.632062  0.997023
# ..   ...  ...  ...  ...  ...       ...       ...       ...       ...
# 787  990    0    1    1    1  0.381596  1.343350  0.331182  1.444601
# 788  991    0    1    1    1  0.574865  1.362194  0.678388  1.562372
# 789  992    0    1    0    1  0.505604  0.705540  0.134996  1.175010
# 790  993    0    1    0    1  0.706988  0.507645 -0.705823  1.201910
# 791  994    0    1    0    1 -0.092176  0.735930  0.161353  0.608609
#
#        ols_sv    ols_lv       ols_pd
# 0    1.102436  0.973649  1770.086466
# 1    0.870328  0.717294  6423.888440
# 2    0.155012  0.576377   519.428981
# 3    0.183000  0.910906  2092.752731
# 4    0.027868  0.939363   960.798019
# ..        ...       ...          ...
# 787  0.381596  1.575492 -3703.498146
# 788  0.574865  1.806863 -1146.724450
# 789  0.505604  0.840836 -3983.153329
# 790  0.706988  0.640490 -6766.495251
# 791 -0.092176  0.614758 -4035.690811
#
# [792 rows x 12 columns]

# %%
rf_ols_c = rf_ols.copy(deep = True)

# %%
rf_ols_c['osvpc'] = rf_ols_c['ols_svp'].round()
rf_ols_c['olvpc'] = rf_ols_c['ols_lvp'].round()
rf_ols_c['opdpc'] = rf_ols_c['ols_pdp'].round()
rf_ols_c['oinpc'] = rf_ols_c['ols_inp'].round()
rf_ols_c['osvc'] = rf_ols_c['ols_sv'].round()
rf_ols_c['olvc'] = rf_ols_c['ols_lv'].round()

# %%
rf_ols_c.loc[rf_ols_c['osvpc']< 0,'osvpc']=0
rf_ols_c.loc[rf_ols_c['olvpc']< 0,'olvpc']=0
rf_ols_c.loc[rf_ols_c['opdpc']< 0,'opdpc']=0
rf_ols_c.loc[rf_ols_c['osvc']< 0,'osvc']=0
rf_ols_c.loc[rf_ols_c['olvc']< 0,'olvc']=0
rf_ols_c.loc[rf_ols_c['oinpc']< 0,'oinpc']=0

# %%
rf_ols_c['olspdv'] = rf_ols_c['ols_pd'].round()
rf_ols_c.loc[rf_ols_c['olspdv']< 0,'olspdv']=0

# %%
rf_ols_c.to_csv('/home/yelhe/script/mt/model/rp_result_rf_ols_new.csv', index = False)

# %%
rf_ols_c.columns
# Out:
# Index(['id', 'svp', 'lvp', 'pdp', 'inp', 'ols_svp', 'ols_lvp', 'ols_pdp',
#        'ols_inp', 'ols_sv', 'ols_lv', 'ols_pd', 'osvpc', 'olvpc', 'opdpc',
#        'oinpc', 'osvc', 'olvc', 'olspdv'],
#       dtype='object')

# %%
plt.hist(rf_ols_c['olspdv'])
# Out:
# (array([439., 114.,  87.,  71.,  34.,  21.,  14.,   6.,   4.,   2.]),
#  array([   0.,  770., 1540., 2310., 3080., 3850., 4620., 5390., 6160.,
#         6930., 7700.]),
#  <BarContainer object of 10 artists>)
